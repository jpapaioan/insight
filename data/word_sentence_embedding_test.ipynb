# %%
# import everything
import os
import pandas as pd
import re
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS, remove_stopwords
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
from profanity_check import predict, predict_prob
from itertools import compress
from nltk.tokenize import sent_tokenize, word_tokenize
import string


pickled_data = '/Users/johnpapaioannou/Desktop/insight/project/nlp_models/full_transcripts.pkl'
specials = pd.read_pickle(pickled_data)

# %%
# load in pre-trained word2vec model
import gensim.downloader as api
w2v_path = '~/gensim-data/word2vec-google-news-300'
w2c_model = api.load('word2vec-google-news-300')

# %%
from gensim.test.utils import get_tmpfile
w2v_model = w2c_model
temp_path = get_tmpfile('w2v')
w2v_model.save(temp_path)

# %% [markdown]
# # collecting functions to help various tasks(clean-up, preprocessing, profanity checker)

# %%
# collection of annoying punctuation specific to these comedy transcripts
def init_clean(single_special):
    single_special = re.sub("[\(\[].*?[\)\]]", "", single_special)
    single_special = re.sub("-", " ", single_special)
    single_special = re.sub("♪", "", single_special)
    return single_special

# filter out sentences that are 2 or less words!
def short_sents_filter(text):
    for sentence in text:
        words = sentence.split(" ")
        if len(words) < 3:
            text.remove(sentence)
    return text


# lemmatizing
stemmer = SnowballStemmer('english')
#comedy_cliche = ['like', 'know', 'say', 'look', 'come', 'right', 'go', 'think']

def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 2:
            #if token not in comedy_cliche:
            result.append(token)
    return result

def profane_filter(text):
    cleaned_up = predict(text)
    cleaned_up = 1 - cleaned_up
    clean_list = list(compress(text, cleaned_up))
    cleaned_up_final = " ".join(clean_list)
    return cleaned_up_final


# remove ellipsis ( why was this so difficult!!!!)
def punctuation_clean_up(spec_sents):
    for i in range(len(spec_sents)):
        spec_sents[i].translate(str.maketrans('', '', string.punctuation))
        spec_sents[i] = spec_sents[i].replace('\u2026', '')
        spec_sents[i] = spec_sents[i].replace('”', '')
        spec_sents[i] = spec_sents[i].replace('“', '')
        spec_sents[i] = spec_sents[i].replace('–', '')
        spec_sents[i] = spec_sents[i].replace('!', '')
        spec_sents[i] = spec_sents[i].replace('.', '')
        spec_sents[i] = spec_sents[i].replace('?', '')
        spec_sents[i] = spec_sents[i].replace(',', '')
        spec_sents[i] = spec_sents[i].replace('\n', ' ')

    return spec_sents

# %%
# initial cleaning of bizarre special unicode text 
special = init_clean(specials.iloc[1,1])

comedian = specials.iloc[1,0]

# remove stop words here using gensim, which doesn't require tokenization first
print(len(special))
special = remove_stopwords(special)
print(len(special))
special = gensim.parsing.preprocessing.strip_numeric(special)
print(len(special))
special = gensim.parsing.preprocessing.strip_short(special, minsize=3)
print(len(special))

# sentence tokenizing BEFORE stripping punctuation
spec_sents = sent_tokenize(special)

# clean up all punctuation, retain apostrophe's though for semantic retention in word embeddings
spec_sents = punctuation_clean_up(spec_sents)
print(spec_sents)
# Out:
# 50406
# 35676
# 35599
# 34051
# ['Okay ready and Take cue Adam', 'And action Dan', 'perfect day You sweetest smile You way Yeah style walkin’ talkin’ And jammin’ jawin’ world Then got hit electric car ‘Cause didn’t hear comin’ Fuck cars', 'You should one', 'electric car', 'But decency I’m driving head window go Here comes Sandman Sandman coming', 'Watch out How Tesla’s driving themselves', 'Those Teslas that’s pretty cool', 'They drive themselves', 'Holy shit man', 'got accident Tesla there didn’t know exchange information with started screaming Hey fucker', 'What fuck And Tesla’s know fucking windshield wipers flappin’ about', 'And like What fuck mean', 'You it And fucking lights going off', 'Like it’s saying Okay', 'All right And uh Then court I’m like I’m going fucking destroy thing And Tesla shows neck brace say Oh fucking break', 'What liar', 'He’s fucking liar Oh Grandma’s roommate Why talk much', 'Don’t know came nursing home grandma said hello polite Now you’re telling That grandma rude ‘Cause didn’t share Her unsugared candy Well guess calls For death pillow face You somebody’s house and uh ring doorbell guy answers says Hey shoes off', 'And go Oh God', 'Okay And goes Hey socks off And you’re like Take socks off And goes Roll pants You’re like Roll pants up puts grapes down goes Start stomping grapes You’re like What fuck doing He’s like Making wine You wine Oh Oh Oh no no no no Oh God mother’s friend son Who moved Hollywood And asked help wife’s putting lotion face', 'Don’t lot lotion face LA', 'wife fucking lathers lotion', 'She says she’s looking me', 'She puts lot lotion', 'Like there’s much', 'Doesn’t rub either', 'She puts forehead cheeks nose Then out me wife date lemon meringue pie', 'And like She likes him', 'She likes him', 'know does', 'don’t shit', 'Daddy shaved beard today Mustache sideburns went away Daddy’s lips small Doesn’t chin Daddy big mistake father shave dad beard then literally years shave beard', 'Like didn’t ask us fucking came nowhere shaved', 'was Any time father shaved beard time saw look vulnerable', 'When came bathroom like like Dad dimples didn’t know Dad dimples It’ll grow back Why’d it', 'don’t know', 'was itchy It’s itchy fucking years went friend’s house heated toilet seat', 'sat heated toilet seat', 'I’ve got relax', 'went lot better usually go', 'came said like heated toilet seat', 'Where’d that goes don’t heated toilet seat You walking street baby', 'And uh And baby goes And you’re going Yeah that’s great And then And mother goes He ‘hi’ back And go Oh yeah And kid goes You go There is Then mother goes No it And kid goes And go Hey great The mother goes No it And kid goes And go There is', 'That it right And mother’s like No', 'Say it', 'Say hi And kid’s like And And mother’s like What fuck', 'Say it', 'You said earlier And kid’s like And you’re like Hey sentence', 'That’s better ‘Hi’ And mother’s like What the', 'I’m mad you baby And like hands baby like I’ve got walk off', 'This discouraging me', 'said earlier And you’re holding baby like Say it', 'ahead it', 'Say ‘Hi’', 'Come on upset mother And kid’s looking you And you’re like Come on out It’s gonna feel better', 'And kid’s like And you’re like You it', 'Come on And kid’s like Help me', 'She She She won’t let vaccinated Come on there’s proof that’s good bad yet', 'I’ve getting sick lot hands shaking heart’s beating fast I’m sweating cheap suit How longer last', 'I’m alcoholic lawyer Facing trial life And need sober quickly want things right Put bottle down son There’s innocent man needs Put bottle down son There’s left fear Wait day it', 'Shit', 'The trial week', 'And got chair', 'Well let’s whiskey sours memory wife fool pretty hardcore', 'pretty good', 'It’s fun', 'You know it’s nice', 'love other fucking pretty hard and gets crazy', 'gets pretty fucking nuts it’s her else', 'So we’re like Let’s fucking Let’s all know', 'do uh safe word', 'It’s Really life wanted able flip', 'Wouldn’t great', 'growing up going Man I’ve got flip going', 'Everybody love fli ...

# %%
# now word tokenize to prepare for tf-idf and word embedding
spec_sents2 = spec_sents
for i in range(len(spec_sents)):
    spec_sents2[i] = word_tokenize(spec_sents[i])

tot_words = 0
for i in range(len(spec_sents2)):
    tot_words += len(spec_sents2[i])
print(tot_words)
# Out:
# 6876

# %% [markdown]
# # word embedding -> sentence embedding

# %%
def word2sent_vec(w2v, special_sentences):
    
    no_of_sentences = len(special_sentences)
    word_vec_dim = len(w2v['word'])
    sentence_vec = np.zeros(word_vec_dim, dtype=np.float32)
    sentence_vec = list(np.zeros(no_of_sentences))
    
    errors = 0
    for i in range(no_of_sentences):
        no_of_words = 0
        sent_vec = np.zeros(word_vec_dim, dtype=np.float32)
    
        for j in range(len(special_sentences[i])):
            try:
                w2v_sents = w2v[special_sentences[i][j]]
                no_of_words += 1
                sent_vec += w2v_sents
            except:
                errors += 1
                pass
        sent_vec = sent_vec/no_of_words
        sentence_vec[i] = sent_vec
    print('errors: ', errors)
    return sentence_vec

# %% [markdown]
# # Playing around with tf-idf

# %%
# use gensim's tools to get tf-idf scores for words where each doc = sentence
from gensim import corpora, models

# build the corpus
dictionary = gensim.corpora.Dictionary(spec_sents2)
print(dictionary)
# prune filler words using filter_extremes
bow_corpus = [dictionary.doc2bow(doc) for doc in spec_sents2]
# Out:
# Dictionary(2575 unique tokens: ['Ali', 'Ladies', 'Wong', 'gentlemen', 'stage']...)

# %%
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

from pprint import pprint

#for doc in corpus_tfidf:
 #   pprint(doc)

for i in range(len(spec_sents2)):
    print(spec_sents2[i])
    print(corpus_tfidf[i])
    print('\n\n')
# Out:
# ['Ladies', 'gentlemen', 'welcome', 'stage', 'Ali', 'Wong']
# [(0, 0.2920157204642617), (1, 0.4387261467169068), (2, 0.38646683846203317), (3, 0.4387261467169068), (4, 0.40021283455813894), (5, 0.46929588235963543)]
#
#
#
# ['What', 'y', '’', 'all', 'thought', 'Y', '’', 'all', 'wasn', '’', 't', 'gon', '’', 'me']
# [(6, 0.24098326132076706), (7, 0.3896210086773813), (8, 0.597947565635207), (9, 0.1944228325164284), (10, 0.1764867897106934), (11, 0.1125164252922164), (12, 0.2658682929076722), (13, 0.35058137344519075), (14, 0.35058137344519075), (15, 0.18566886496568982)]
#
#
#
# ['I', '’', 'm', 'Osirus', 'shit', 'Tang', 'forever', 'motherfuckers', 'It', '’', 's', 'like', 'ninety', 'seven', 'Aight', 'niggas', 'niggarettes', 'Let', '’', 's', 'like', 'I', '’', 'ma', 'rub', 'ass', 'moonshine', 'Let', '’', 's', 'seventy', 'bomb', 'atomically', 'Socrates', '’', 'philosophies', 'hypotheses', 'Can', '’', 't', 'define', 'How', 'droppin', '’', 'mockeries', 'Lyrically', 'perform', 'armed', 'robbery', 'Flee', 'lottery', 'Possibly', 'spotted', 'Battle', 'scarred', 'shogun', 'Explosion', 'pen', 'hits', 'Oh', 'goodness']
# [(11, 0.044879383432799805), (15, 0.1481153380173083), (16, 0.15540798240340162), (17, 0.15540798240340162), (18, 0.13983625806082844), (19, 0.15540798240340162), (20, 0.15540798240340162), (21, 0.11925155816653953), (22, 0.10128531937236776), (23, 0.06707853862439513), (24, 0.24852906743651054), (25, 0.15540798240340162), (26, 0.07253638513881999), (27, 0.15540798240340162), (28, 0.15540798240340162), (29, 0.15540798240340162), (30, 0.13983625806082844), (31, 0.15540798240340162), (32, 0.08054917674020826), (33, 0.15540798240340162), (34, 0.15540798240340162), (35, 0.15540798240340162), (36, 0.13983625806082844), (37, 0.13072738324885633), (38, 0.13983625806082844), (39, 0.15540798240340162), (40, 0.15540798240340162), (41, 0.07953646949642751), (42, 0.15540798240340162), (43, 0.05358200396451883), (44, 0.13983625806082844), (45, 0.15540798240340162), (46, 0.15540798240340162), (47, 0.15540798240340162), (48, 0.15540798240340162), (49, 0.15540798240340162), (50, 0.15540798240340162), (51, 0.15540798240340162), (52, 0.13983625806082844), (53, 0.15540798240340162), (54, 0.15540798240340162), (55, 0.15540798240340162), (56, 0.1098172326130085), (57, 0.15540798240340162), (58, 0.11515565890628315), (59, 0.15540798240340162), (60, 0.0649774523976351), (61, 0.15540798240340162), (62, 0.15540798240340162)]
#
#
#
# ['heard', 'rumor', 'Asians', 'city', 'Have', 'congregated', 'theater', 'tonight']
# [(63, 0.3111125037681035), (64, 0.3111125037681035), (65, 0.3500983511635375), (66, 0.38908419855897153), (67, 0.32729309237837106), (68, 0.38908419855897153), (69, 0.38908419855897153), (70, 0.3500983511635375)]
#
#
#
# ['Yeah']
# [(71, 1.0)]
#
#
#
# ['Thank', 'coming', 'white', 'boyfriends']
# [(72, 0.4563720837915506), (73, 0.6525166216114832), (74, 0.4563720837915506), (75, 0.3970782048819252)]
#
#
#
# ['really', 'Appreciate', 'it', 'heart']
# [(76, 0.650594517465435), (77, 0.5202166780766725), (78, 0.23847485457417006), (79, 0.49923053335169504)]
#
#
#
# ['I', '’', 'm', 'excited', 'here']
# [(15, 0.0930929944492069), (22, 0.2546381434991194), (43, 0.2694175641452306), (80, 0.7031156216344508), (81, 0.5996129660067834)]
#
#
#
# ['performing', 'all', 'past', 'years', 'years', 'ago', 'gave', 'birth', 'baby', 'girl']
# [(8, 0.3037009392190733), (82, 0.3037009392190733), (83, 0.18473023441296405), (84, 0.2844504152989943), (85, 0.31646761000095247), (86, 0.2585910739057525), (87, 0.31646761000095247), (88, 0.35612451160298886), (89, 0.553621416797832)]
#
#
#
# ['And', 'started', 'come', 'stand', 'up', 'stand', 'comics', 'couldn', '’', 't', 'believe', 'it']
# [(11, 0.11742489831425347), (15, 0.04844214418494151), (78, 0.14904548569659185), (90, 0.12424094126306699), (91, 0.2843898715217659), (92, 0.2605569082156931), (93, 0.3420423479718858), (94, 0.3251325913998623), (95, 0.6502651827997246), (96, 0.31201636520897724), (97, 0.2335459104133646)]
#
#
#
# ['They', 'like', 'Oh', 'God', 'Ali', 'What', 'here']
# [(0, 0.3877042157193343), (6, 0.4282911244079095), (26, 0.3232043145833087), (41, 0.1771974855017381), (81, 0.531355650635818), (98, 0.3830475792073195), (99, 0.3183204370351645)]
#
#
#
# ['Didn', '’', 't', 'baby', 'like', 'Listen', 'I', '’', 've', 'baby', 'girl', 'born', 'day', 'day']
# [(11, 0.11994447905467032), (15, 0.09896313017030312), (22, 0.13534739048047864), (41, 0.10628444142822666), (83, 0.3877209650623724), (86, 0.2713718765362468), (100, 0.4153428158883799), (101, 0.4153428158883799), (102, 0.349381535186258), (103, 0.4349179475640281), (104, 0.25689237517941693)]
#
#
#
# ['And', 'love', 'much']
# [(90, 0.2977531691281311), (105, 0.6244450852571964), (106, 0.7220882119050879)]
#
#
#
# ['But', 'I', '’', 'm', 'verge', 'putting', 'garbage']
# [(15, 0.06517625584389947), (22, 0.17827722576234717), (43, 0.18862459193049774), (107, 0.2957479694233648), (108, 0.5470823241884482), (109, 0.4922652226907692), (110, 0.5470823241884482)]
#
#
#
# ['need', 'miss', 'her', 'don', '’', 't', 'jail', 'It', '’', 's', 'sexist', 'people', 'ask', 'me', 'Well', 'you', '’', 're', 'here', 'who', '’', 's', 'taking', 'care', 'baby', 'Who', 'fuck', 'think', 'taking', 'care', 'baby']
# [(10, 0.11489947865595423), (11, 0.073252386920855), (15, 0.120877351909291), (23, 0.10948597528656309), (56, 0.11949621108306727), (81, 0.19464307687761023), (83, 0.23678860731164542), (111, 0.18795772662429405), (112, 0.22824154205180225), (113, 0.19464307687761023), (114, 0.38928615375522047), (115, 0.09343928355652278), (116, 0.14202152809654348), (117, 0.18795772662429405), (118, 0.2536577997923981), (119, 0.2536577997923981), (120, 0.14031573639655007), (121, 0.1386857832116992), (122, 0.10003192096904186), (123, 0.22824154205180225), (124, 0.4564830841036045), (125, 0.14202152809654348), (126, 0.19464307687761023), (127, 0.09684139571559414)]
#
#
#
# ['The', 'taking', 'care', 'baby', 'okay']
# [(83, 0.3082948969523437), (114, 0.5068442101987797), (124, 0.5943335153324648), (128, 0.34942692708354844), (129, 0.41561003149902714)]
#
#
#
# ['The', 'windows', 'open', 'she', '’', 's', 'got', 'gummy', 'vitamins', 'lap', 'she', '’', 's', 'fine']
# [(15, 0.08203148969307594), (56, 0.16218840093681458), (128, 0.18213210089954138), (130, 0.3097849747470365), (131, 0.13969092126432278), (132, 0.344281651782927), (133, 0.344281651782927), (134, 0.28960571228155185), (135, 0.5102180704913226), (136, 0.344281651782927), (137, 0.344281651782927)]
#
#
#
# ['tried', 'stay', 'home', 'mom', 'weeks']
# [(138, 0.3791186200332068), (139, 0.3431915322732199), (140, 0.44053638222427893), (141, 0.49012231483100444), (142, 0.5515400770220765)]
#
#
#
# ['like', 'stay', 'home', 'part']
# [(41, 0.19788955642759626), (138, 0.47830442057896083), (140, 0.5557904252375664), (143, 0.6505087300918864)]
#
#
#
# ['Not', 'crazy', 'mom', 'aspect', 'shit', 'relentless']
# [(60, 0.21485022070399923), (139, 0.28770831047334144), (144, 0.46237348184927995), (145, 0.5138619334319932), (146, 0.3593965786838536), (147, 0.5138619334319932)]
#
#
#
# ['stupid', 'naive', 'thought', 'stay', 'home', 'mom', 'chillaxing', 'getting', 'shit', 'home', 'Watch', 'Wendy', 'Williams', 'brunch', 'sassy', 'girlfriends']
# [(12, 0.19459110005112354), (60, 0.11923071546734082), (138, 0.3527550984095721), (139, 0.15966317181910997), (140, 0.20495096607350866), (148, 0.28516668855992083), (149, 0.28516668855992083), (150, 0.28516668855992083), (151, 0.28516668855992083), (152, 0.28516668855992083), (153, 0.21882126916550534), (154, 0.28516668855992083), (155, 0.28516668855992083), (156, 0.28516668855992083), (157, 0.23987889430552217)]
#
#
#
# ['understand', 'price', 'pay', 'staying', 'home', 'you', '’', 've', 'got', 'ta', 'mom']
# [(15, 0.05473110071229941), (104, 0.2841462761731763), (127, 0.17539220038530415), (131, 0.18640251222834658), (138, 0.2841462761731763), (139, 0.2572192204673579), (158, 0.34041557340696105), (159, 0.4133747348847256), (160, 0.45940684065667176), (161, 0.23811417040123015), (162, 0.3864476791789072)]
#
#
#
# ['Oh', 'that', '’', 's', 'job']
# [(15, 0.117355764814934), (26, 0.459780226346691), (56, 0.2320297230644785), (163, 0.72992739872141), (164, 0.4338178974358993)]
#
#
#
# ['It', '’', 's', 'wack', 'ass', 'job']
# [(15, 0.08273041022822322), (23, 0.2997358729860879), (32, 0.3599285002872217), (56, 0.1635702703189454), (163, 0.5145652046004782), (165, 0.694429965678314)]
#
#
#
# ['You', 'workers']
# [(166, 0.4345267966305609), (167, 0.9006589049190504)]
#
#
#
# ['You', '’', 're', 'solitary', 'confinement', 'day', 'long', 'human', 'Tamagotchi', 'That', 'don', '’', 't', 'got', 'reset', 'button', 'stakes', 'extremely', 'high']
# [(11, 0.0937429820368066), (15, 0.07734494331858664), (103, 0.1699557398027316), (115, 0.11957667795091904), (122, 0.12801344727018618), (131, 0.13171023015350852), (166, 0.1201744551492388), (168, 0.29208662920066114), (169, 0.15270030028509465), (170, 0.324612474336517), (171, 0.324612474336517), (172, 0.2595607840648053), (173, 0.2730602294919219), (174, 0.2595607840648053), (175, 0.22150798464732674), (176, 0.324612474336517), (177, 0.324612474336517), (178, 0.324612474336517)]
#
#
#
# ['toy', 'Tamagotchi', 'communicative', 'human', 'baby']
# [(83, 0.25032914497251296), (168, 0.48258664737056), (174, 0.42884732147275145), (179, 0.5363259732683686), (180, 0.48258664737056)]
#
#
#
# ['Okay']
# [(181, 1.0)]
#
#
#
# ['Because', 'toy', 'tell', 'poos']
# [(180, 0.5689266777800894), (182, 0.38476388220976493), (183, 0.6322805569555017), (184, 0.35846964662718783)]
#
#
#
# ['With', 'human', 'baby', 'guess', 'check', 'intuition', 'sniffing', 'ass', 'Twenty', 'times', 'day']
# [(32, 0.2018877906482668), (83, 0.1818045960236127), (103, 0.20393553324509275), (174, 0.3114555999650897), (185, 0.35048444111942334), (186, 0.32765403259753556), (187, 0.32765403259753556), (188, 0.32765403259753556), (189, 0.35048444111942334), (190, 0.35048444111942334), (191, 0.3114555999650897)]
#
#
#
# ['And', 'can', '’', 't', 'phone', 'sniff', 'afar']
# [(11, 0.15792993066760985), (15, 0.06515197868891431), (90, 0.1670971277934932), (192, 0.5468785444192363), (193, 0.3648479037588867), (194, 0.5468785444192363), (195, 0.4600278567499463)]
#
#
#
# ['You', 'got', 'ta', 'flip', 'baby', 'over', 'plant', 'face', 'baby', '’', 's', 'ass', 'good', 'yoga', 'inhale', 'mouth', 'everything', 'inside', 'nose', 'singed', 'poo', 'poo', 'smelling']
# [(15, 0.02963806460937918), (32, 0.12894392904424903), (56, 0.058598842028135784), (83, 0.23223394395780247), (131, 0.10094095731447285), (161, 0.12894392904424903), (166, 0.092100093769263), (196, 0.2487786550639091), (197, 0.16254411508829336), (198, 0.22385128274325475), (199, 0.16254411508829336), (200, 0.2487786550639091), (201, 0.1739965381019461), (202, 0.20926970469415748), (203, 0.2487786550639091), (204, 0.20926970469415748), (205, 0.2487786550639091), (206, 0.4975573101278182), (207, 0.2487786550639091), (208, 0.2487786550639091), (209, 0.22385128274325475)]
#
#
#
# ['That', '’', 's', 'know', 'love', 'baby', 'anybody', 'entire', 'world']
# [(15, 0.06966194871737413), (56, 0.1377319869587466), (83, 0.2729238448535936), (105, 0.3746923734173079), (169, 0.27506388992418174), (210, 0.4918720445697075), (211, 0.4918720445697075), (212, 0.206277700429737), (213, 0.3990093522580125)]
#
#
#
# ['told', 'husband', 'Till', 'death', 'part', 'And', 'ever', 'sniffed', 'ass', 'check', 'shit', 'pants']
# [(32, 0.19360350303630705), (60, 0.1561761759915973), (90, 0.11413097493020506), (143, 0.3142090380560604), (187, 0.3142090380560604), (214, 0.37352994792415206), (215, 0.37352994792415206), (216, 0.37352994792415206), (217, 0.1800334740985492), (218, 0.3142090380560604), (219, 0.3361026208794423), (220, 0.2548881281879687)]
#
#
#
# ['I', '’', 've', 'licked', 'it', 'haven', '’', 't', 'sniffed', 'it']
# [(11, 0.15451132893698077), (15, 0.12748335629026655), (22, 0.1743532118869704), (78, 0.3922373601790514), (104, 0.3309262968632121), (219, 0.4814301002799066), (221, 0.45006994680485257), (222, 0.4814301002799066)]
#
#
#
# ['Because', 'sniffing', 'disgusting']
# [(182, 0.4314216629456444), (190, 0.637916667261961), (223, 0.637916667261961)]
#
#
#
# ['Okay']
# [(181, 1.0)]
#
#
#
# ['And', 'haven', '’', 't', 'licked', 'ass', 'yet', 'grow', 'up']
# [(11, 0.14631527209808654), (15, 0.06036049942718248), (32, 0.2626055397946271), (90, 0.15480828501957902), (97, 0.29100585923504213), (221, 0.4261959765861692), (222, 0.4558926300309904), (224, 0.5066593944102633), (225, 0.3887826179115026)]
#
#
#
# ['Grow', 'fuck', 'up']
# [(97, 0.44804078074540876), (116, 0.43675498618899805), (226, 0.7800670104728776)]
#
#
#
# ['And', 'learn', 'long', 'term', 'committed', 'lasting', 'relationship', 'love', 'sacrifices', 'greater', 'good']
# [(90, 0.1106783095326895), (105, 0.23211348727079953), (175, 0.24717730804496815), (199, 0.23666964114272737), (227, 0.3622300012889622), (228, 0.3622300012889622), (229, 0.3622300012889622), (230, 0.3259349175908794), (231, 0.3047036546669652), (232, 0.3622300012889622), (233, 0.3047036546669652)]
#
#
#
# ['dream', 'goal', 'longest', 'time', 'trophy', 'wife', 'order', 'trophy', 'wife', 'trophy']
# [(234, 0.2089331849752932), (235, 0.24837860230336312), (236, 0.24837860230336312), (237, 0.24837860230336312), (238, 0.12747663292714745), (239, 0.7451358069100894), (240, 0.44698262973808134)]
#
#
#
# ['commemorative', 'plaque']
# [(241, 0.7071067811865475), (242, 0.7071067811865475)]
#
#
#
# ['joined', 'moms', '’', 'group', 'Los', 'Angeles']
# [(15, 0.05943202967746194), (243, 0.4196401979649164), (244, 0.4196401979649164), (245, 0.49886592143396424), (246, 0.49886592143396424), (247, 0.3828023343920884)]
#
#
#
# ['Yeah', 'don', '’', 't', 'bitches', 'particularly', 'interesting', 'fun', 'you', '’', 're', 'new', 'mom', 'maternity', 'leave', 'it', '’', 's', 'like', 'The', 'Walking', 'Dead', 'got', 'ta', 'hook', 'crew', 'survive']
# [(11, 0.0861677033955528), (15, 0.10664216120847948), (41, 0.07635437909880888), (56, 0.07028244748272242), (71, 0.15465314002138525), (78, 0.10937124398932617), (115, 0.10991380362377182), (122, 0.11766880587059467), (127, 0.11391575091537337), (128, 0.15784963341955402), (131, 0.12106685534679767), (139, 0.167061708474131), (161, 0.15465314002138525), (248, 0.29838085795204494), (249, 0.29838085795204494), (250, 0.2509944995641727), (251, 0.29838085795204494), (252, 0.22896109767056225), (253, 0.2509944995641727), (254, 0.2684833945317359), (255, 0.19119957272355464), (256, 0.22896109767056225), (257, 0.19119957272355464), (258, 0.2684833945317359), (259, 0.29838085795204494)]
#
#
#
# ['hate', 'moms', 'clothes', 'wore']
# [(247, 0.4353975135038701), (260, 0.5105539918593164), (261, 0.47729672038272875), (262, 0.5674076729680836)]
#
#
#
# ['You', 'know', 'fucking', 'clothes', 'moms', 'wear', 'cheesy', 'ass', 'animal', 'print', 'and', 'loud', 'metallic', 'shiny', 'shoes']
# [(32, 0.16745086855456268), (166, 0.11960424046274705), (212, 0.11397064539032953), (247, 0.24790789676071326), (260, 0.29070070999269587), (263, 0.22595768289842885), (264, 0.29070070999269587), (265, 0.3230722235398294), (266, 0.22595768289842885), (267, 0.2717645884760359), (268, 0.3230722235398294), (269, 0.3230722235398294), (270, 0.29070070999269587), (271, 0.2717645884760359), (272, 0.2583291964455624)]
#
#
#
# ['And', 'that', '’', 's', 'bedazzled', 'rhinestones', 'I', '’', 'm', 'like', 'Oh', 'That', 'looks', 'nice']
# [(15, 0.11053619248154603), (22, 0.15117534358785464), (26, 0.21653114220171352), (41, 0.11871368109806912), (43, 0.15994969280161658), (56, 0.10927320941813352), (90, 0.14174765412027154), (164, 0.20430431640292118), (169, 0.21822900192425324), (273, 0.46391432206983796), (274, 0.417430571170276), (275, 0.39023932000116895), (276, 0.46391432206983796)]
#
#
#
# ['think', 'I', '’', 'ma', 'that', 'The', 'glitter', 'better', 'you', '’', 're', 'mom', 'need', 'sparkle']
# [(15, 0.10419044025562353), (22, 0.1424965457069037), (44, 0.39346637522048233), (120, 0.24189077803291728), (122, 0.17244537079537253), (125, 0.24483139818052063), (127, 0.16694521339528556), (128, 0.2313309662960639), (139, 0.24483139818052063), (164, 0.19257544695777673), (277, 0.32402096798293756), (278, 0.43728154889553594), (279, 0.43728154889553594)]
#
#
#
# ['compensate', 'light', 'inside', 'died']
# [(201, 0.3911761008947443), (280, 0.5593000029501738), (281, 0.5593000029501738), (282, 0.47047664287258306)]
#
#
#
# ['lot', 'young', 'women', 'anxiety', 'giving', 'birth']
# [(84, 0.39212776671360666), (283, 0.545602584210361), (284, 0.458954533895764), (285, 0.267476927583324), (286, 0.301810661631513), (287, 0.41866548487764177)]
#
#
#
# ['Well', 'let', 'tell', 'something']
# [(111, 0.5484603310269787), (184, 0.419638976940364), (288, 0.5050768226340191), (289, 0.5176792419637332)]
#
#
#
# ['Giving', 'birth', 'ain', '’', 't', 'compared', 'breastfeeding']
# [(11, 0.157280611832399), (15, 0.06488411048473582), (84, 0.3914288281248523), (290, 0.49005869826826776), (291, 0.41791924477938763), (292, 0.40356509166091636), (293, 0.49005869826826776)]
#
#
#
# ['Breastfeeding', 'brutal']
# [(294, 0.6688829984297351), (295, 0.7433676979877771)]
#
#
#
# ['chronic', 'physical', 'torture']
# [(296, 0.5773502691896257), (297, 0.5773502691896257), (298, 0.5773502691896257)]
#
#
#
# ['thought', 'supposed', 'beautiful', 'bonding', 'ceremony', 'feel', 'like', 'sitting', 'lily', 'pad', 'meadow', 'bunnies', 'gather', 'feet', 'fat', 'Hawaiian', 'man', 'version', 'Somewhere', 'Over', 'Rainbow', 'play']
# [(12, 0.16518258520793214), (41, 0.06194454533410283), (299, 0.24206950276316608), (300, 0.2178143807901697), (301, 0.24206950276316608), (302, 0.24206950276316608), (303, 0.17937092201255275), (304, 0.24206950276316608), (305, 0.24206950276316608), (306, 0.24206950276316608), (307, 0.2178143807901697), (308, 0.14504901487118066), (309, 0.2178143807901697), (310, 0.2178143807901697), (311, 0.24206950276316608), (312, 0.13724060966315335), (313, 0.24206950276316608), (314, 0.2178143807901697), (315, 0.20362604398554912), (316, 0.24206950276316608), (317, 0.17937092201255275), (318, 0.24206950276316608)]
#
#
#
# ['No']
# [(319, 1.0)]
#
#
#
# ['It', '’', 's', 'like', 'all']
# [(8, 0.8042728055007254), (15, 0.12486748629995448), (23, 0.45240033151590775), (41, 0.2682104135368166), (56, 0.24688150864702196)]
#
#
#
# ['Breastfeeding', 'savage', 'ritual', 'reminds', 'body', 'cafeteria', 'now']
# [(294, 0.3810710909988354), (320, 0.2767054202819959), (321, 0.4235059649453067), (322, 0.2465557231428631), (323, 0.4235059649453067), (324, 0.4235059649453067), (325, 0.4235059649453067)]
#
#
#
# ['don', '’', 't', 'belong', 'more']
# [(11, 0.216310284493301), (15, 0.08923604908788141), (115, 0.2759210840569528), (326, 0.7490375828479282), (327, 0.5550288670148441)]
#
#
#
# ['When', 'baby', 'girl', 'hungry', 'she', '’', 'd', 'yank', 'nipple', 'forth', 'like', 'bear', 'fucking', 'Leonardo', 'DiCaprio', 'The', 'Revenant']
# [(15, 0.037988785987122), (41, 0.08159840724984091), (83, 0.14883369936993734), (86, 0.20834199813442697), (128, 0.16869076566438607), (135, 0.23628200778966485), (266, 0.22302121732885324), (328, 0.31887369198851506), (329, 0.31887369198851506), (330, 0.31887369198851506), (331, 0.17434215606706005), (332, 0.28692286710196113), (333, 0.21273534914304523), (334, 0.28692286710196113), (335, 0.28692286710196113), (336, 0.28692286710196113), (337, 0.28692286710196113)]
#
#
#
# ['It', '’', 's', 'frightening']
# [(15, 0.10630303587623753), (23, 0.3851405205357675), (56, 0.21017684145447227), (338, 0.892295993110557)]
#
#
#
# ['saw', 'movie', 'nipples', 'like', 'feel', 'you', 'Leo', 'didn', '’', 't', 'classes', 'breastfeeding', 'assumed', 'gon', 'na', 'easy', 'intuitive', 'thing', 'baby', 'sucks', 'nipple', 'like', 'straw', 'nurse', 'promised', 'particularly', 'easy', 'time', 'nipples', 'look', 'like', 'fingers']
# [(9, 0.11068742081134304), (11, 0.06405704902717763), (15, 0.026425918604859842), (41, 0.17028547864110316), (83, 0.10353232205270874), (127, 0.08468494057287869), (238, 0.11384390209273207), (258, 0.19959048795293877), (292, 0.16436348104830767), (308, 0.13291318759674198), (336, 0.19959048795293877), (339, 0.2218162547383377), (340, 0.19959048795293877), (341, 0.2218162547383377), (342, 0.17020962240890555), (343, 0.39918097590587753), (344, 0.14492773437247), (345, 0.2218162547383377), (346, 0.13957114455950645), (347, 0.17736472116753985), (348, 0.09390946723904545), (349, 0.3404192448178111), (350, 0.1865892478337066), (351, 0.2218162547383377), (352, 0.1513622409290755), (353, 0.2218162547383377), (354, 0.2218162547383377), (355, 0.14492773437247)]
#
#
#
# ['You', 'spin', 'DVDs', 'them', 'that', '’', 's', 'Command', 'hook', 'like', 'are']
# [(15, 0.05064977072658634), (41, 0.10879370086372617), (56, 0.1001420960742922), (164, 0.1872321915916816), (166, 0.15739383440827134), (253, 0.3576300511682274), (356, 0.425148605576221), (357, 0.425148605576221), (358, 0.38254914068208457), (359, 0.425148605576221), (360, 0.3150305862740909)]
#
#
#
# ['But', 'apparently', 'baby', 'latch', 'specific', 'angle']
# [(83, 0.219780848900374), (107, 0.2545519030905832), (361, 0.4708767638909339), (362, 0.4708767638909339), (363, 0.4708767638909339), (364, 0.4708767638909339)]
#
#
#
# ['You', 'got', 'ta', 'tilt', 'head', 'geometry', 'properly']
# [(131, 0.20795571872256657), (161, 0.26564665278306976), (166, 0.18974202052130482), (365, 0.5125267819233469), (366, 0.33486881020954135), (367, 0.4611721111859074), (368, 0.5125267819233469)]
#
#
#
# ['And', 'it', '’', 's', 'stressful', 'they', '’', 're', 'hungry', 'they', '’', 're', 'crying', 'makes', 'hormones', 'spray', 'milk', 'face', 'neck', 'slippery', 'hard', 'grip', 'got', 'ta', 'slam', 'right', 'time']
# [(15, 0.0939771945288025), (56, 0.061935609370592615), (78, 0.09638216776335133), (90, 0.08034199216385539), (122, 0.20738860004261614), (131, 0.10668879256557802), (161, 0.13628632484170075), (197, 0.17179979107374618), (238, 0.13495248979940327), (335, 0.23659794503166867), (369, 0.2629447454333913), (370, 0.2629447454333913), (371, 0.1948392543809532), (372, 0.2629447454333913), (373, 0.2017693693702419), (374, 0.23659794503166867), (375, 0.22118605478267583), (376, 0.13366387831780377), (377, 0.2629447454333913), (378, 0.2629447454333913), (379, 0.2629447454333913), (380, 0.2629447454333913), (381, 0.3308999975618424)]
#
#
#
# ['And', 'time', 'it', 'like', 'parallel', 'parking']
# [(41, 0.1663537095452492), (78, 0.2382877363413303), (90, 0.19863126022319624), (238, 0.3336459850839125), (382, 0.6500840313740575), (383, 0.5849462618752628)]
#
#
#
# ['don', '’', 't', 'know', 'it']
# [(11, 0.4116720153829098), (15, 0.16983003956038947), (78, 0.5225284957559361), (115, 0.5251206110076603), (212, 0.5028878845542712)]
#
#
#
# ['It', '’', 's', 'mystery']
# [(15, 0.10630303587623753), (23, 0.3851405205357675), (56, 0.21017684145447227), (384, 0.892295993110557)]
#
#
#
# ['properly', 'trained', 'it']
# [(78, 0.2628960442213483), (367, 0.6453544806384516), (385, 0.7172191187166175)]
#
#
#
# ['went', 'forth', 'forth', 'forth', 'concerned', 'strangers', 'start', 'gathering', 'outside', 'car']
# [(334, 0.7620223881772836), (386, 0.2374615238443792), (387, 0.25400746272576125), (388, 0.28229293206949485), (389, 0.2166161061232046), (390, 0.22572199338202764), (391, 0.28229293206949485), (392, 0.20288558048465483)]
#
#
#
# ['Those', 'people', 'gather', 'outside', 'Asian', 'women', '’', 's', 'cars', 'we', '’', 're', 'parking', 'Are', 'helpful', 'racist', 'time']
# [(15, 0.08352176783694933), (56, 0.08256745074101761), (121, 0.1916534670015831), (122, 0.13823669608066916), (238, 0.1799075389283329), (286, 0.1939059414203207), (310, 0.31541288396693745), (383, 0.31541288396693745), (389, 0.26898229686965347), (393, 0.2802895007232821), (394, 0.2013346811646458), (395, 0.31541288396693745), (396, 0.35053626721059283), (397, 0.31541288396693745), (398, 0.31541288396693745), (399, 0.22056430482027925)]
#
#
#
# ['I', '’', 'm', 'like', 'Thank', 'you']
# [(15, 0.12289973637146087), (22, 0.3361688050891418), (41, 0.2639837646492871), (43, 0.3556803366697598), (72, 0.721508942777217), (127, 0.393846549921848)]
#
#
#
# ['Thank', 'you', 'fuck', 'you', 'For', 'assuming', 'correctly', 'me']
# [(10, 0.23037298858933639), (72, 0.3557043785740328), (116, 0.2847525876909594), (127, 0.3883332111012649), (400, 0.3470450865398365), (401, 0.5085828595632368), (402, 0.45762336590016883)]
#
#
#
# ['you', 'mom', 'saw', 'struggle', 'breastfeeding', 'discouraging', 'it', 'like', 'Why', 'breastfeeding']
# [(41, 0.1079451682443864), (78, 0.1546223998265716), (127, 0.1610471467829331), (139, 0.23618166294166126), (292, 0.6251470327327135), (352, 0.287848782409199), (403, 0.2950310384480926), (404, 0.3795654621989365), (405, 0.4218326740743584)]
#
#
#
# ['raised', 'formula', 'look', 'shiny', 'hair', 'is', 'She', 'like', 'Are', 'falling', 'bullshit', 'slogan', '‘', 'breast', 'best', '’', 'like', 'No', 'breast', 'free']
# [(15, 0.03140755682465859), (41, 0.13492437549174588), (270, 0.23721595777905816), (319, 0.15348042240081997), (346, 0.16588216740473785), (393, 0.21080033742837523), (406, 0.16893256973925613), (407, 0.17989604275150292), (408, 0.5272631562594822), (409, 0.2636315781297411), (410, 0.2636315781297411), (411, 0.2636315781297411), (412, 0.17224854586266972), (413, 0.23721595777905816), (414, 0.1758807867429291), (415, 0.2636315781297411), (416, 0.2636315781297411), (417, 0.16042863940449292)]
#
#
#
# ['Come', 'on', 'Mom', 'know', 'is']
# [(212, 0.23500730475910916), (414, 0.4444357081867308), (418, 0.4053894532060703), (419, 0.6661744542781185), (420, 0.3729872058059802)]
#
#
#
# ['Local', 'organic', 'free', 'range', 'farm', 'mouth', 'milk', 'squirting', 'outta', 'titties', 'squirting', 'like', 'holes', 'titty', 'like', 'Bellagio', 'fountain', 'just', 'Woo']
# [(41, 0.12836190192787214), (202, 0.21097762641615325), (374, 0.22567820971700175), (412, 0.16387069327287865), (421, 0.2508090228592549), (422, 0.2508090228592549), (423, 0.21097762641615325), (424, 0.22567820971700175), (425, 0.2508090228592549), (426, 0.22567820971700175), (427, 0.1802579108890406), (428, 0.2508090228592549), (429, 0.20054739657474863), (430, 0.22567820971700175), (431, 0.5016180457185098), (432, 0.22567820971700175), (433, 0.19245708177689277)]
#
#
#
# ['Woo', 'woo', 'woo']
# [(423, 0.4234533911103401), (434, 0.9059178911784186)]
#
#
#
# ['Woo', 'woo', 'woo', 'For', 'free']
# [(400, 0.3102130957975752), (412, 0.29702573687237477), (423, 0.38240995810941625), (434, 0.81811134374843)]
#
#
#
# ['body', 'food', 'factory']
# [(320, 0.4770389230610864), (435, 0.6569648786588145), (436, 0.5838073433021617)]
#
#
#
# ['wasn', '’', 't', 'let', 'waste']
# [(11, 0.1874721098489695), (13, 0.5841300910762763), (15, 0.07733922793490401), (288, 0.44298323274933565), (437, 0.6491769743709168)]
#
#
#
# ['shat', 'juicy', 'hamburgers', 'Would', 'wait', 'line', 'Out', 'again']
# [(438, 0.35447141516443187), (439, 0.39394423316461946), (440, 0.2688183605084427), (441, 0.39394423316461946), (442, 0.35447141516443187), (443, 0.35447141516443187), (444, 0.39394423316461946), (445, 0.29190847883634347)]
#
#
#
# ['No', 'pop', 'squat', 'husband', '’', 's', 'head', 'morning']
# [(15, 0.0605012161300342), (56, 0.11961986226968539), (217, 0.2447683242053299), (319, 0.2956534396878192), (366, 0.33180697752139693), (446, 0.4569554394570414), (447, 0.5078405549395307), (448, 0.5078405549395307)]
#
#
#
# ['And', 'tell', 'open', 'wide', 'Because', 'breakfast', 'way', 'Animal', 'style']
# [(90, 0.125174416432692), (134, 0.3446122579834007), (182, 0.24929980938071053), (184, 0.2322630025970264), (449, 0.40967312581122417), (450, 0.40967312581122417), (451, 0.40967312581122417), (452, 0.27955139015557734), (453, 0.40967312581122417)]
#
#
#
# ['Yeah', 'you', '’', 'd', 'like', 'got', 'secret', 'menu', 'right', 'here', 'Work', 'work', 'work', 'work', 'work', 'stop', 'breastfeeding', 'half', 'months']
# [(15, 0.034306084316127264), (41, 0.07368810996286346), (71, 0.14925270459275772), (81, 0.220965853452006), (127, 0.10993785135874605), (131, 0.11683924163810117), (292, 0.2133764022984031), (333, 0.1921123993590136), (376, 0.14638075660534133), (454, 0.28796149914506775), (455, 0.1921123993590136), (456, 0.28796149914506775), (457, 0.2014011368660906), (458, 0.23025459095908302), (459, 0.24222985639139546), (460, 0.6615764705822559)]
#
#
#
# ['anymore']
# [(461, 1.0)]
#
#
#
# ['end', 'felt', 'like', 'The', 'Giving', 'Tree']
# [(41, 0.1347941525624345), (128, 0.2786638804507238), (290, 0.4739740152448658), (462, 0.5267542656125858), (463, 0.4739740152448658), (464, 0.4211937648771459)]
#
#
#
# ['understand', 'depressing', 'ass', 'book', 'about']
# [(32, 0.30108135946366027), (162, 0.48864035438422065), (465, 0.445745353385081), (466, 0.445745353385081), (467, 0.5226880321204955)]
#
#
#
# ['And', 'know', 'it', '’', 's', 'breastfeeding']
# [(15, 0.12090613454702923), (56, 0.23904932970258147), (78, 0.3720007413061873), (90, 0.3100913928015482), (212, 0.35801811263412614), (292, 0.752009928259982)]
#
#
#
# ['It', '’', 's', 'mom', 'beautiful', 'branches', 'apples', 'little', 'freeloader', 'comes', 'life', 'takes', 'shit', 'sad', 'ass', 'tree', 'stump', 'deflated', 'titties']
# [(15, 0.03607666212571521), (23, 0.13070731532510158), (32, 0.1569558141734886), (56, 0.07132890263483022), (60, 0.12661319900118878), (139, 0.16954913729618024), (303, 0.22438901217593607), (432, 0.27248091939784413), (468, 0.30282353457014394), (469, 0.30282353457014394), (470, 0.2020275487569256), (471, 0.30282353457014394), (472, 0.30282353457014394), (473, 0.18729842934578844), (474, 0.19785533225094615), (475, 0.2421383042255443), (476, 0.30282353457014394), (477, 0.2421383042255443), (478, 0.30282353457014394)]
#
#
#
# ['People', 'kept', 'asking', 'me', 'Ali', 'skinny', 'baby', 'She', 'sucked', 'life', 'outta', 'me']
# [(0, 0.2169458426125548), (10, 0.3510307845133786), (83, 0.1808539332831208), (406, 0.2482912020386471), (429, 0.30982698748399545), (473, 0.23965687011104347), (479, 0.28711595998550676), (480, 0.3486517454308551), (481, 0.32594071793236645), (482, 0.3874765033777148), (483, 0.3486517454308551)]
#
#
#
# ['turns', 'out', 'breastfeeding', 'free', 'buy', 'pillows', 'pumps', 'support', 'breastfeeding', 'clogged', 'duct']
# [(292, 0.502220293776911), (412, 0.22141673098165818), (484, 0.28506608117868726), (485, 0.3388849637056562), (486, 0.3388849637056562), (487, 0.2030612265447293), (488, 0.30492902941542444), (489, 0.30492902941542444), (490, 0.30492902941542444), (491, 0.26004172588901797)]
#
#
#
# ['That', '’', 's', 'like', 'traffic', 'jam', 'kidney', 'stone', 'titty', 'lactation', 'consultant']
# [(15, 0.046498020129064455), (41, 0.09987590506548179), (56, 0.09193347042309453), (169, 0.18359989242281247), (433, 0.29949424151614), (492, 0.3511916715242893), (493, 0.3902992676243286), (494, 0.3902992676243286), (495, 0.3511916715242893), (496, 0.3902992676243286), (497, 0.3902992676243286)]
#
#
#
# ['lactation', 'consultant', 'white', 'NPR', 'listener', 'dreadlocks', 'Named', 'Indigo', 'That', 'pay', 'rush', 'house', 'Roto', 'Rooter', 'titty']
# [(75, 0.18058749872136967), (158, 0.21989490878335516), (169, 0.13959758265860184), (433, 0.22771621259746364), (492, 0.26702362265944907), (495, 0.26702362265944907), (498, 0.26702362265944907), (499, 0.29675853049143275), (500, 0.24962981661533884), (501, 0.29675853049143275), (502, 0.29675853049143275), (503, 0.29675853049143275), (504, 0.20755380699548176), (505, 0.29675853049143275), (506, 0.29675853049143275)]
#
#
#
# ['Indigo', 'push', 'ups', 'dipping', 'titty', 'bowl', 'scalding', 'hot', 'water', 'beat', 'titty', 'like', 'interim']
# [(41, 0.07724039736104951), (433, 0.46323593677345953), (498, 0.2715988830403339), (507, 0.2715988830403339), (508, 0.30184327742776906), (509, 0.30184327742776906), (510, 0.24135448865289882), (511, 0.30184327742776906), (512, 0.25390704646666296), (513, 0.30184327742776906), (514, 0.30184327742776906), (515, 0.23161796838672977)]
#
#
#
# ['This', 'women', 'need', 'maternity', 'leave']
# [(120, 0.37292621894201916), (255, 0.4319969874282026), (256, 0.5173155097733759), (286, 0.37292621894201916), (516, 0.5173155097733759)]
#
#
#
# ['First', 'World', 'country', 'Canada', 'France', 'Germany', 'Women', 'years', 'paid', 'maternity', 'leave', 'new', 'baby']
# [(83, 0.15428918199867264), (89, 0.2311960351431494), (255, 0.21182091959282476), (256, 0.2536551184122301), (257, 0.21182091959282476), (517, 0.33056197155670686), (518, 0.2974399927521877), (519, 0.33056197155670686), (520, 0.33056197155670686), (521, 0.27806487720186307), (522, 0.33056197155670686), (523, 0.27806487720186307), (524, 0.2974399927521877)]
#
#
#
# ['US', 'jack', 'shit']
# [(60, 0.3214268565747302), (525, 0.6917342432665265), (526, 0.6466749667065934)]
#
#
#
# ['US', 'zero', 'federal', 'policy', 'maternity', 'leave']
# [(255, 0.2981641335468), (256, 0.35705094070253235), (525, 0.4186835648320293), (527, 0.4653068451510307), (528, 0.4653068451510307), (529, 0.4186835648320293)]
#
#
#
# ['Maternity', 'leave', 'bond', 'baby']
# [(83, 0.3113211357359315), (255, 0.42740734253704804), (530, 0.6001675241086892), (531, 0.6001675241086892)]
#
#
#
# ['Fuck', 'baby']
# [(83, 0.504123745210976), (532, 0.8636314315229957)]
#
#
#
# ['Maternity', 'leave', 'new', 'moms', 'hide', 'heal', 'demolished', 'ass', 'bodies']
# [(32, 0.21684498550583908), (247, 0.3210349683097845), (255, 0.2680881136343478), (257, 0.2680881136343478), (530, 0.3764506675243856), (533, 0.3764506675243856), (534, 0.41837102569585105), (535, 0.35192882997727865), (536, 0.35192882997727865)]
#
#
#
# ['couldn', '’', 't', 'work', 'topless', 'beating', 'wet', 'titty', 'trying', 'establish', 'dominance', 'coworkers']
# [(11, 0.10487171749676476), (15, 0.04326348953954408), (94, 0.2903746459547801), (433, 0.27866059563443846), (460, 0.20857893931360658), (537, 0.3631489735538681), (538, 0.3631489735538681), (539, 0.3631489735538681), (540, 0.3631489735538681), (541, 0.3631489735538681), (542, 0.23270235582490442), (543, 0.2609972901615019)]
#
#
#
# ['You', '’', 'd', 'fired']
# [(15, 0.09429206911935027), (166, 0.29301199393572325), (333, 0.5280309892589123), (544, 0.7914772589867998)]
#
#
#
# ['People', 'don', '’', 't', 'tell', 'crazy', 'shit', 'goes', 'pregnant', 'birth']
# [(11, 0.15749303676771326), (15, 0.06497174368257287), (60, 0.22802221235628645), (84, 0.3919574962329288), (115, 0.20089497611342083), (146, 0.3814303877196206), (184, 0.30919350188633105), (479, 0.4041101511408636), (545, 0.4587552457664111), (546, 0.331873265307574)]
#
#
#
# ['When', 'pregnant', 'lot', 'moms', 'highly', 'recommended', 'me', 'Ali', 'sure', 'hospital', 'steal', 'bunch', 'free', 'diapers', 'Yeah', 'duh', 'know', 'baby', 'No']
# [(0, 0.17768406686474503), (10, 0.14375149262125), (71, 0.1644865189239801), (83, 0.14812389113913588), (212, 0.1119530455804486), (247, 0.24351923226154007), (285, 0.15557952208982082), (319, 0.18475580049688767), (331, 0.17351069452390183), (412, 0.2073483867028528), (546, 0.19311988612070222), (547, 0.2669535936785269), (548, 0.25375604573776195), (549, 0.31735293981936474), (550, 0.31735293981936474), (551, 0.25375604573776195), (552, 0.31735293981936474), (553, 0.31735293981936474), (554, 0.23515514663772552)]
#
#
#
# ['For', 'you', 'For', 'me']
# [(10, 0.3044605900571022), (127, 0.2566102895019115), (400, 0.9173085132188767)]
#
#
#
# ['What', 'fuck', 'need', 'diapers', 'for', 'Oh', 'you', '’', 'll', 'see', 'Winter', 'coming', 'And', 'see']
# [(6, 0.2336573506447352), (15, 0.04500612910553178), (26, 0.17632647411707328), (74, 0.2642180169636858), (90, 0.11542849592559037), (116, 0.2115148662116463), (120, 0.20897440415603616), (127, 0.14422739378362961), (548, 0.30207084412062507), (555, 0.3777764984345035), (556, 0.30207084412062507), (557, 0.24207553253059697), (558, 0.579769911175782)]
#
#
#
# ['Nobody', 'told', 'crazy', 'shit', 'comes', 'pussy', 'birth']
# [(60, 0.23291940277730672), (84, 0.40037549409446943), (146, 0.38962229683989485), (220, 0.3801373046536972), (470, 0.37165269002155543), (559, 0.5012596910513366), (560, 0.31583399291583447)]
#
#
#
# ['You', 'know', 'happens', 'baby', 'comes', 'out']
# [(83, 0.33659681593755897), (166, 0.26697732279754444), (212, 0.2544021655594704), (470, 0.4811144348494069), (487, 0.43211776626045745), (561, 0.5766353851723054)]
#
#
#
# ['You', 'know', 'exits']
# [(166, 0.3296119300302685), (212, 0.3140865595447052), (562, 0.8903401645972688)]
#
#
#
# ['Her', 'house']
# [(504, 0.6393277068952767), (563, 0.7689343815931415)]
#
#
#
# ['Her', 'living', 'room', 'pillows', 'Bob', 'Marley', 'poster', 'All', 'food', 'went', 'bad', 'refrigerator', 'months']
# [(392, 0.23022797033756873), (436, 0.2561419903413239), (457, 0.22404455797822967), (488, 0.28823942270441805), (563, 0.26946362840257426), (564, 0.20929798267355215), (565, 0.3203368550675122), (566, 0.3203368550675122), (567, 0.23022797033756873), (568, 0.2561419903413239), (569, 0.3203368550675122), (570, 0.3203368550675122), (571, 0.3203368550675122)]
#
#
#
# ['wear', 'cartoonishly', 'large', 'pad']
# [(272, 0.450053235051743), (314, 0.5064498971242736), (572, 0.5628465591968042), (573, 0.47345996464600004)]
#
#
#
# ['That', '’', 's', 'like', 'size', 'toddler', 'mattress', 'it', '’', 's', 'held', 'strength', 'mesh', 'fishnet', 'underwear', 'that', '’', 's', 'exclusively', 'available', 'hospital']
# [(15, 0.1089590167394536), (41, 0.07801321706237319), (56, 0.21542810887306402), (78, 0.11174739024043986), (164, 0.13425947906673158), (169, 0.14341014733051463), (551, 0.2437693325714507), (574, 0.30486333480031075), (575, 0.30486333480031075), (576, 0.30486333480031075), (577, 0.2743163336858807), (578, 0.2743163336858807), (579, 0.30486333480031075), (580, 0.2743163336858807), (581, 0.30486333480031075), (582, 0.2743163336858807), (583, 0.2437693325714507)]
#
#
#
# ['You', 'can', '’', 't', 'shit', 'Amazon', 'anything', 'got', 'ta', 'snatch', 'shit', 'day']
# [(11, 0.13636408525905228), (15, 0.0562552642122649), (60, 0.3948624148072149), (103, 0.24722766962571543), (131, 0.19159348960213932), (161, 0.24474522518775593), (166, 0.17481286910092841), (193, 0.31502673650554), (584, 0.47220050146470305), (585, 0.3623407542896885), (586, 0.4248864836805546)]
#
#
#
# ['It', '’', 's', 'material', 'package', 'fancy', 'Korean', 'pears', 'in']
# [(15, 0.053596350835409166), (23, 0.19418190919400966), (56, 0.10596792122839196), (587, 0.40480416123619367), (588, 0.3333576753382627), (589, 0.32333273343106195), (590, 0.40480416123619367), (591, 0.44988187497732185), (592, 0.44988187497732185)]
#
#
#
# ['It', '’', 's', 'Dac', 'Biet', 'okay']
# [(15, 0.07905166404446634), (23, 0.28640761562775024), (56, 0.156296844428128), (129, 0.41751930727549696), (593, 0.5970638310081371), (594, 0.5970638310081371)]
#
#
#
# ['Number', 'extra', 'large', 'Dac', 'Biet', 'hospital', 'underwear']
# [(551, 0.3377244485785243), (573, 0.35528909255744884), (583, 0.3377244485785243), (593, 0.38004506782243436), (594, 0.38004506782243436), (595, 0.4223656870663444), (596, 0.4223656870663444)]
#
#
#
# ['For', 'months', 'walking', 'house', 'knot', 'giant', 'diaper', 'nipples', 'bleeding']
# [(349, 0.30139999091062436), (400, 0.26802584598089196), (457, 0.2747134902181333), (504, 0.2747134902181333), (597, 0.39278282987640173), (598, 0.35342638332364557), (599, 0.39278282987640173), (600, 0.39278282987640173), (601, 0.31406993677088946)]
#
#
#
# ['Like', 'defeated', 'sumo', 'wrestler']
# [(602, 0.3362965039996599), (603, 0.5437231714140345), (604, 0.5437231714140345), (605, 0.5437231714140345)]
#
#
#
# ['section']
# [(606, 1.0)]
#
#
#
# ['Yeah']
# [(71, 1.0)]
#
#
#
# ['Which', 'original', 'intention', 'having', 'contractions', 'hours']
# [(607, 0.3241637324099442), (608, 0.4750510074627349), (609, 0.34142193608010707), (610, 0.379851736196609), (611, 0.4274513718296719), (612, 0.4750510074627349)]
#
#
#
# ['Yeah']
# [(71, 1.0)]
#
#
#
# ['And', 'like', 'Cut', 'out', 'The', 'nurse', 'like', 'Keep', 'going', 'like', 'Bitch', 'said', 'cut', 'out']
# [(41, 0.28182011145097063), (90, 0.11216718891085002), (128, 0.19420497688035265), (350, 0.3088026239211874), (487, 0.4399389735488126), (613, 0.3303194964615946), (614, 0.3303194964615946), (615, 0.36710283302399066), (616, 0.3303194964615946), (617, 0.23098831344274878), (618, 0.2567528233368024)]
#
#
#
# ['Your', 'price', 'way', 'high', 'You', 'need', 'cut', 'Cut', 'it', 'cut', 'it', 'need', 'cut', 'The', 'nurse', 'big', 'hip', 'hop', 'fan', 'so', 'She', 'appreciate', 'Dave', 'Coulier', 'reference']
# [(78, 0.15793979053437157), (120, 0.2383512989222531), (128, 0.11397300208382358), (159, 0.19385447923787788), (166, 0.07975838019153897), (173, 0.181226880304633), (350, 0.181226880304633), (406, 0.13805283438655352), (452, 0.14701225841234836), (614, 0.19385447923787788), (616, 0.5815634377136336), (619, 0.2154415021969176), (620, 0.19385447923787788), (621, 0.1548390670402869), (622, 0.19385447923787788), (623, 0.1548390670402869), (624, 0.2154415021969176), (625, 0.2154415021969176), (626, 0.2154415021969176), (627, 0.2154415021969176), (628, 0.1548390670402869)]
#
#
#
# ['Look', 'section', 'joke', 'okay']
# [(129, 0.40330059208944447), (606, 0.47493978382044927), (629, 0.4482848683079969), (630, 0.640953595052692)]
#
#
#
# ['major', 'surgery']
# [(631, 0.6437251081308498), (632, 0.7652568099415553)]
#
#
#
# ['But', 'it', '’', 's', 'fast']
# [(15, 0.10857927115903601), (56, 0.21467729563437732), (78, 0.3340737797380801), (107, 0.4926962825797168), (633, 0.7666611268593989)]
#
#
#
# ['They', 'anesthesia', 'back', 'curtain', 'husband', 'human', 'cadaver', 'side']
# [(99, 0.19889914428793307), (174, 0.3459687145041468), (217, 0.20854068243105384), (634, 0.43267614891383366), (635, 0.3459687145041468), (636, 0.43267614891383366), (637, 0.3893224317089902), (638, 0.3893224317089902)]
#
#
#
# ['And', 'minutes', 'later', 'hold', 'baby', 'curtain', 'like', 'bloody', 'Simba', 'it', '’', 's', 'over']
# [(15, 0.04763629211783084), (41, 0.1023208682009695), (56, 0.09418400268064502), (78, 0.1465660617412119), (83, 0.18663101217730899), (90, 0.12217414960837922), (204, 0.3363523534889782), (637, 0.3597888470873467), (639, 0.3998537975234438), (640, 0.3998537975234438), (641, 0.3197238966512496), (642, 0.3363523534889782), (643, 0.3597888470873467)]
#
#
#
# ['like', 'What', 'fuck', 'pushing', 'perfectly', 'good', 'emergency', 'exit', 'One', 'best', 'friends', 'God', 'bless', 'her', 'labor', 'hours']
# [(6, 0.19846906343889753), (41, 0.08211288300656672), (98, 0.17750331483733559), (116, 0.17966118885023416), (117, 0.2377717594754555), (199, 0.2096555888129777), (407, 0.21896388488679216), (610, 0.2565796340641189), (644, 0.320884182015403), (645, 0.320884182015403), (646, 0.2887319080397609), (647, 0.2887319080397609), (648, 0.2096555888129777), (649, 0.2887319080397609), (650, 0.26992403345109756), (651, 0.320884182015403)]
#
#
#
# ['The', 'baby', '’', 's', 'head', 'kept', 'going', 'out', 'out', 'out']
# [(15, 0.051606626560433154), (56, 0.10203394173257939), (83, 0.20218611738727016), (128, 0.22916134647700118), (366, 0.28302635673123766), (481, 0.3643862594572341), (487, 0.7786901950118497), (617, 0.27256558394795233)]
#
#
#
# ['And', 'emergency', 'section']
# [(90, 0.25356243519040583), (606, 0.6149202239192607), (646, 0.7467122669913744)]
#
#
#
# ['Before', 'shit', 'went', 'down', 'friend', 'kindest', 'polite', 'dainty', 'lady', 'burp', 'anybody']
# [(60, 0.14655045141594347), (210, 0.2948431543653783), (392, 0.251912072140787), (652, 0.35050789365340557), (653, 0.35050789365340557), (654, 0.35050789365340557), (655, 0.251912072140787), (656, 0.251912072140787), (657, 0.35050789365340557), (658, 0.2948431543653783), (659, 0.35050789365340557)]
#
#
#
# ['After', 'shit', 'went', 'down', 'bitter', 'nasty', 'raw', 'ass', 'bitch', 'met', 'life']
# [(32, 0.1988021203454133), (60, 0.16036979934575576), (392, 0.2756667623447284), (473, 0.23723444134507085), (655, 0.2756667623447284), (660, 0.3451276068695573), (661, 0.2682629648702422), (662, 0.38355992786921483), (663, 0.3066952858698998), (664, 0.38355992786921483), (665, 0.38355992786921483)]
#
#
#
# ['went', 'house', 'pay', 'visit', 'shortly', 'after', 'opens', 'door', 'Look', 'pussy', 'Ali']
# [(0, 0.20460158017739408), (158, 0.27077900364330165), (392, 0.26263596695317803), (504, 0.2555821477248536), (560, 0.20717892915434352), (629, 0.2555821477248536), (666, 0.3654290117662016), (667, 0.3288133904190856), (668, 0.3654290117662016), (669, 0.3654290117662016), (670, 0.3654290117662016)]
#
#
#
# ['Look', 'shit']
# [(60, 0.5131117975421148), (629, 0.858321783029593)]
#
#
#
# ['Look', 'this', 'No', 'Hello', 'Ali']
# [(0, 0.3637088638772055), (319, 0.37818428787201247), (629, 0.45433418693886146), (671, 0.49846958627705523), (672, 0.5194237430838874)]
#
#
#
# ['Welcome']
# [(673, 1.0)]
#
#
#
# ['Come', 'meet', 'beautiful', 'new', 'baby', 'No', 'just', 'Come', 'on', 'look', 'shit']
# [(60, 0.18321008284735613), (83, 0.2045232098267771), (257, 0.2807863378519751), (303, 0.32469228986468984), (319, 0.25510300236607436), (346, 0.2757162006853736), (418, 0.5333035567326118), (420, 0.24533865138688488), (427, 0.31492793888550036), (674, 0.3942815773633053)]
#
#
#
# ['You', 'look', 'happened', 'me', 'Just', 'door', 'open', 'entire', 'cul', 'sac', 'see', 'Come', 'on', 'And', 'pussy', 'looked', 'crazy']
# [(10, 0.15274855803027737), (90, 0.10303514388679767), (134, 0.28366158675536246), (146, 0.23584939903303584), (166, 0.12484013764480739), (211, 0.28366158675536246), (346, 0.21218249599406833), (418, 0.20520680233652058), (420, 0.1888048917172293), (558, 0.25876052416788464), (560, 0.19118325113209084), (667, 0.3034266720688296), (675, 0.24235861354859337), (676, 0.3372153085867265), (677, 0.24987295023746559), (678, 0.25876052416788464), (679, 0.3372153085867265)]
#
#
#
# ['looked', 'cuckoo', 'Cocoa', 'Puffs']
# [(678, 0.40505592557531755), (680, 0.5278666805031749), (681, 0.5278666805031749), (682, 0.5278666805031749)]
#
#
#
# ['When', 'saw', 'it', 'like', 'Because', 'pussy', 'straight', 'looked', 'like', 'hanging', 'dicks', 'side']
# [(41, 0.21864162318576272), (78, 0.15659289354397626), (182, 0.2599706539092158), (331, 0.23357350515124115), (352, 0.2915171009577152), (560, 0.24220461625727516), (638, 0.38440260972378215), (678, 0.327816338970574), (683, 0.3415967483671327), (684, 0.42720847108043153), (685, 0.327816338970574)]
#
#
#
# ['process', 'giving', 'birth', 'baby', 'girl', 'friend', 'dudes']
# [(83, 0.23994626550671133), (84, 0.36947289700422165), (86, 0.3358841755072275), (284, 0.43243880088588005), (656, 0.36947289700422165), (686, 0.3944774196171503), (687, 0.46257044433513633)]
#
#
#
# ['You', 'French', 'braid', 'shit']
# [(60, 0.27498416195037906), (166, 0.24348111395372932), (688, 0.6576855851485186), (689, 0.6576855851485186)]
#
#
#
# ['like', 'Star', 'Wars', 'monster']
# [(41, 0.1461549615796156), (690, 0.5711505134975838), (691, 0.5711505134975838), (692, 0.5711505134975838)]
#
#
#
# ['mean', 'women', 'we', '’', 're', 'accustomed', 'seeing', 'other', '’', 's', 'pussies', 'place']
# [(15, 0.10044320897643866), (56, 0.0992955480255404), (122, 0.16624333646468284), (286, 0.23319112490382526), (399, 0.26525045069754144), (693, 0.42155462525636533), (694, 0.29483657027017873), (695, 0.3123674851551607), (696, 0.42155462525636533), (697, 0.3793152735943031), (698, 0.3793152735943031)]
#
#
#
# ['It', '’', 's', 'like', 'men', 'urinal', 'you', '’', 're', 'like', 'Hey', 'what', '’', 's', 'up', 'dude']
# [(15, 0.17350175389404096), (23, 0.2095347991328526), (41, 0.24844992901513854), (56, 0.22869243773819106), (97, 0.278824879680528), (122, 0.19144158338327333), (127, 0.1853355404279113), (699, 0.33126081843120697), (700, 0.29541351536201776), (701, 0.3395262694562669), (702, 0.4854515474595626), (703, 0.3395262694562669)]
#
#
#
# ['What', '’', 's', 'going', 'on', 'holding', 'dicks', 'hands', 'other']
# [(6, 0.3216762129879753), (15, 0.06195996458903426), (56, 0.12250402395953743), (420, 0.29119264155772756), (617, 0.32724777911665964), (683, 0.41586110996586834), (695, 0.38537753853562057), (704, 0.43748954809634766), (705, 0.41586110996586834)]
#
#
#
# ['We', '’', 're', 'like', 'going', 'bathroom', 'What', '’', 's', 'up', 'girl', 'holding', 'pussies', 'casual', 'like', 'manicure', 'told', 'turned', 'dudes']
# [(6, 0.2128445038526677), (15, 0.08199448631394349), (41, 0.17612090812153758), (56, 0.08105761988872255), (86, 0.22484128764267336), (97, 0.19765306921549114), (122, 0.13570889575755413), (220, 0.2348237988976566), (617, 0.216531059402818), (686, 0.26406367861403085), (697, 0.3096452346190321), (705, 0.2751641186027445), (706, 0.22484128764267336), (707, 0.2751641186027445), (708, 0.3441263506353197), (709, 0.3441263506353197), (710, 0.3096452346190321)]
#
#
#
# ['And', 'started', 'laughing']
# [(90, 0.25016121427671384), (96, 0.6282501726191246), (711, 0.7366960618027222)]
#
#
#
# ...
#
#
#
# ['And', 'think', 'that', '’', 's', 'finally', 'leave', 'you', 'boom', 'baby', 'comes', 'out', 'got', 'ta', 'stay']
# [(15, 0.05444838224021455), (56, 0.10765251346986382), (83, 0.2133196400713268), (90, 0.1396453103716735), (125, 0.2558905312202029), (127, 0.174486196042925), (131, 0.1854396331200495), (140, 0.3284728155223007), (161, 0.23688417002554865), (164, 0.20127415759664677), (255, 0.2928628030933988), (470, 0.30490828556807886), (487, 0.27385644189874453), (1040, 0.3507026083164549), (2505, 0.4570337328922485)]
#
#
#
# ['That', '’', 's', 'real', 'miracle', 'life', 'right', 'there']
# [(15, 0.0704571082547648), (56, 0.13930413509773054), (169, 0.2782036194248932), (376, 0.30063369283181385), (473, 0.3657906506532723), (765, 0.3789693168533735), (812, 0.42504926261902704), (2506, 0.5914092185953902)]
#
#
#
# ['child', 'toll', 'marriage', 'baby', 'hasn', '’', 't', 'come', 'resentful', 'husband']
# [(11, 0.1305056788930814), (15, 0.053838453382973404), (83, 0.21093004098789067), (92, 0.28958216430359707), (217, 0.21781294418998193), (791, 0.36135138441721226), (932, 0.31607004805691336), (936, 0.4066327207775111), (2507, 0.45191405713781), (2508, 0.45191405713781)]
#
#
#
# ['resentment', 'especially', 'asks', 'shit', 'house']
# [(60, 0.22433555796087276), (504, 0.3752634358209447), (1630, 0.4827866254783834), (2509, 0.5365482203071028), (2510, 0.5365482203071028)]
#
#
#
# ['Hey', 'wash', 'dishes', 'No', 'Can', 'water', 'plants', 'jack', 'shit', 'anymore']
# [(18, 0.3587456030781827), (60, 0.16669764816456653), (319, 0.23211097267815098), (461, 0.25086633607067704), (515, 0.3059361909831611), (526, 0.33537706595411915), (699, 0.2720597507541033), (898, 0.3587456030781827), (2511, 0.398694381154135), (2512, 0.398694381154135)]
#
#
#
# ['I', '’', 'm', 'busy', 'makin', '’', 'eyeball', 'OK']
# [(15, 0.13928264972856969), (22, 0.19049057105941694), (43, 0.20154681047476125), (1039, 0.43315393310130235), (1635, 0.31255940372423496), (2513, 0.5845616225265547), (2514, 0.5259891328355002)]
#
#
#
# ['Are', 'makin', '’', 'foot']
# [(15, 0.07590791238462379), (393, 0.509476545198806), (2514, 0.5733196071204784), (2515, 0.6371626690421509)]
#
#
#
# ['didn', '’', 't', 'think', 'so']
# [(11, 0.23451073966606484), (15, 0.09674441474429492), (125, 0.45466878285358775), (342, 0.6231318029099155), (628, 0.583633691023517)]
#
#
#
# ['You', 'change', 'channel', 'there', '’', 's', 'like', 'crazy', 'double', 'standard', 'society', 'takes', 'little', 'considered', 'great', 'dad']
# [(15, 0.03994433552465988), (41, 0.0857988501809561), (56, 0.07897586560316991), (146, 0.23450168523736764), (166, 0.12412676387134504), (474, 0.2190668235668483), (477, 0.26809724341052976), (765, 0.21484954351527163), (1166, 0.26809724341052976), (1350, 0.25728188937116614), (1881, 0.3016928015836919), (2172, 0.3016928015836919), (2516, 0.335288359756854), (2517, 0.3016928015836919), (2518, 0.335288359756854), (2519, 0.335288359756854)]
#
#
#
# ['And', 'takes', 'little', 'considered', 'shitty', 'mom']
# [(90, 0.17669256025852864), (139, 0.3237770963226279), (474, 0.3778316185487508), (477, 0.46239596556412615), (1917, 0.48644462578582315), (2517, 0.5203393086680221)]
#
#
#
# ['People', 'praise', 'husband', 'coming', 'doctor', '’', 's', 'appointments', 'me']
# [(10, 0.24291802466160153), (15, 0.06388907916643666), (56, 0.12631816910920432), (74, 0.3750743762790522), (217, 0.258474520726655), (479, 0.39737621271698215), (795, 0.45111072219306786), (1641, 0.38542606504526916), (2520, 0.45111072219306786)]
#
#
#
# ['Oh', 'God']
# [(26, 0.6448801696504569), (98, 0.7642836952281513)]
#
#
#
# ['can', '’', 't', 'believe', 'comes', 'doctor', '’', 's', 'appointments']
# [(11, 0.17260878976556718), (15, 0.14241510959685297), (56, 0.1407878790277804), (91, 0.4180390381398239), (193, 0.39875883469403317), (470, 0.39875883469403317), (1641, 0.42957650987511675), (2520, 0.502785325595924)]
#
#
#
# ['supportive', 'Guess', 'doctor', 'appointments']
# [(1641, 0.4002621336788802), (2520, 0.4684751670056628), (2521, 0.556920659628392), (2522, 0.556920659628392)]
#
#
#
# ['Me']
# [(2523, 1.0)]
#
#
#
# ['I', '’', 'm', 'star', 'show']
# [(15, 0.08322930550190759), (22, 0.22765790232787322), (43, 0.24087136616985483), (2039, 0.6286168494462466), (2524, 0.6986176377426249)]
#
#
#
# ['There', '’', 's', 'camera', 'I', '’', 'm', 'there']
# [(15, 0.15586928518185078), (22, 0.2131753610573616), (43, 0.22554824553240208), (56, 0.15408832762513236), (765, 0.41918890788279656), (1358, 0.5019778606876844), (2525, 0.6541748195164282)]
#
#
#
# ['But', 'he', '’', 's', 'hero', 'playing', 'Candy', 'Crush', 'blood', 'drawn']
# [(15, 0.04876175858816965), (56, 0.09640921653224303), (107, 0.22126449120524808), (982, 0.3272777701676219), (1025, 0.24166771568856332), (1553, 0.3682893047383547), (1815, 0.3682893047383547), (2526, 0.40930083930908756), (2527, 0.40930083930908756), (2528, 0.40930083930908756)]
#
#
#
# ['Meanwhile', 'mushrooms', 'seven', 'months', 'pregnant', 'I', '’', 'm', 'bad', 'mommy']
# [(15, 0.053417633071283326), (22, 0.14611375427192128), (43, 0.1545943244131135), (58, 0.3322460896153168), (457, 0.313599533252317), (546, 0.2728552953570143), (567, 0.3222545760138723), (2290, 0.40345433622987675), (2529, 0.4483817377186567), (2530, 0.4483817377186567)]
#
#
#
# ['You', 'know', 'like', 'berate', 'husband', 'on', 'like', 'daily', 'basis']
# [(41, 0.27024654279401633), (166, 0.19548530506930858), (212, 0.1862775625418895), (217, 0.2545042238639547), (420, 0.2956467571425777), (1908, 0.4441814377126541), (2531, 0.47513128929978704), (2532, 0.5280404100536426)]
#
#
#
# ['Partially', 'mad', 'him']
# [(1177, 0.4345697862574558), (2533, 0.6368473525391108), (2534, 0.6368473525391108)]
#
#
#
# ['But', 'survival', 'leaves', 'me', 'I', '’', 'm', 'fucked']
# [(10, 0.2558240308872481), (15, 0.06728344586533233), (22, 0.18404104245158576), (43, 0.19472294558347142), (107, 0.30530969035929173), (1208, 0.43337338944963405), (2535, 0.5081804720668118), (2536, 0.5647698455028549)]
#
#
#
# ['So', 'chip', 'away', 'self', 'esteem', 'daily', 'basis', 'doesn', '’', 't', 'believe', 'he', '’', 's', 'worthy', 'woman', '’', 's', 'affection', 'leaves', 'me']
# [(10, 0.14109905528836622), (11, 0.08995552210553828), (15, 0.11133001010755568), (56, 0.1467439425451757), (91, 0.21786213777084543), (989, 0.2078142093332342), (1008, 0.21786213777084543), (1012, 0.19960445402320978), (1025, 0.18392055584315464), (1650, 0.18392055584315464), (1658, 0.2802855708118596), (1908, 0.262027887064224), (2531, 0.2802855708118596), (2535, 0.2802855708118596), (2537, 0.3114972873323667), (2538, 0.3114972873323667), (2539, 0.3114972873323667), (2540, 0.3114972873323667)]
#
#
#
# ['got', 'ta', 'keeping', 'down']
# [(131, 0.29057486732157634), (161, 0.37118594939839444), (655, 0.5147008931329558), (2541, 0.7161495849739762)]
#
#
#
# ['People', 'don', '’', 't', 'tell', 'shit', 'goes', 'body', 'pregnant', 'know']
# [(11, 0.16935115358121505), (15, 0.06986365853783834), (60, 0.24519067951958057), (115, 0.21602095338130578), (184, 0.332473595651692), (212, 0.20687498831337434), (320, 0.3831534448531419), (479, 0.434536800319125), (545, 0.49329628583238083), (546, 0.3568609855780251)]
#
#
#
# ['Your', 'nipples', 'huge', 'dark']
# [(349, 0.5023232162715369), (621, 0.4704827316312478), (1362, 0.5234393680513884), (1613, 0.5023232162715369)]
#
#
#
# ['didn', '’', 't', 'know', 'that']
# [(11, 0.2880935503995567), (15, 0.1188493199275185), (164, 0.4393389806112151), (212, 0.35192762855013554), (342, 0.7655097319757083)]
#
#
#
# ['didn', '’', 't', 'know', 'dark', 'baby', 'see', 'like', 'bullseye']
# [(11, 0.15843433565061404), (15, 0.0653600645315684), (41, 0.1403908291602357), (83, 0.25606978329312297), (212, 0.1935392859337076), (342, 0.4209848698502401), (558, 0.4209848698502401), (1362, 0.43868180306141247), (2542, 0.5486251940994905)]
#
#
#
# ['baby', 'easier']
# [(83, 0.42294608151204705), (2543, 0.9061548499752153)]
#
#
#
# ['And', 'then', 'know', 'big', 'big', 'like', 'fingers']
# [(41, 0.14297807884442404), (90, 0.1707200642702501), (212, 0.19710600364173184), (344, 0.3650602951680411), (623, 0.8031333100659879), (1618, 0.3650602951680411)]
#
#
#
# ['Like', 'You', 'you']
# [(127, 0.46804121889510547), (166, 0.45385616539877727), (602, 0.7582558925222419)]
#
#
#
# ['You', 'owe', 'money', 'you', 'nipples', 'look', 'like', 'Whoppers', 'now', 'naked', 'look', 'like', 'Minion']
# [(41, 0.1892814246146723), (127, 0.1411977667411115), (166, 0.1369184473266528), (322, 0.21531315521461192), (346, 0.4654223945836853), (349, 0.2837956595281856), (1138, 0.24673796529143535), (1437, 0.33278326667149116), (2544, 0.36984096090824137), (2545, 0.36984096090824137), (2546, 0.36984096090824137)]
#
#
#
# ['But', 'I', '’', 'm', 'gon', 'na', 'crazy', 'pregnant', 'ladies', 'tries', 'shape', 'right', 'pregnant']
# [(9, 0.2076057471552104), (15, 0.04956455337030032), (22, 0.13557438911756714), (43, 0.14344324528370947), (107, 0.22490730442924584), (146, 0.2909792124642394), (348, 0.1761369536682876), (376, 0.21148717400369915), (546, 0.5063478133164273), (2187, 0.31924581469320734), (2547, 0.416039410427783), (2548, 0.416039410427783)]
#
#
#
# ['No']
# [(319, 1.0)]
#
#
#
# ['Hopefully', 'year', 'kind', 'body', 'where', 'nude', 'scene', 'television', 'people', 'commend', 'courageous']
# [(121, 0.18874640224515501), (320, 0.2255553302284167), (775, 0.2481110673594201), (927, 0.20097892371070766), (2452, 0.31062859442055507), (2549, 0.3452192142806328), (2550, 0.3452192142806328), (2551, 0.3452192142806328), (2552, 0.3452192142806328), (2553, 0.3452192142806328), (2554, 0.3452192142806328)]
#
#
#
# ['For', 'it']
# [(78, 0.47321438808869903), (400, 0.8809472985972759)]
#
#
#
# ['Now', 'I', '’', 'm', 'seven', 'half', 'months', 'pregnant', 'pussy', '’', 's', 'wet', 'again']
# [(15, 0.11718875893097734), (22, 0.16027375738478108), (43, 0.1695761864960373), (56, 0.11584976385226713), (58, 0.3644443291762071), (440, 0.33561658591175436), (455, 0.3281256678651541), (457, 0.343990719825897), (543, 0.3534845298414747), (546, 0.2992979246007013), (560, 0.2788443152503913), (967, 0.3932720724406599)]
#
#
#
# ['But', 'it', '’', 's', 'different']
# [(15, 0.1165221467217913), (56, 0.2303815366664906), (78, 0.35851220553440266), (107, 0.5287383854690503), (1424, 0.7247424750219709)]
#
#
#
# ['It', '’', 's', 'like', 'years', 'old', 'like', 'hot', 'know']
# [(15, 0.08163080692861197), (23, 0.2957519624260152), (41, 0.35067947842039693), (56, 0.1613961917852497), (89, 0.47923094828371626), (212, 0.24171897926332717), (510, 0.5478873043570147), (921, 0.4105745922104179)]
#
#
#
# ['And', 'like', 'Why', 'different', 'And', 'looked', 'up', 'pussy', '’', 's', 'wet', 'my', 'body', '’', 's', 'secreting', 'mucus', 'protect', 'baby', 'bacteria', 'attacking', 'it']
# [(15, 0.07607768468769961), (41, 0.0817059263209453), (56, 0.15041684690403326), (78, 0.11703688653479499), (83, 0.14902981178983163), (90, 0.19511859587860295), (97, 0.1833902321158283), (320, 0.20861652234226916), (403, 0.2233150837771327), (543, 0.2294783633564945), (560, 0.18102273704486832), (678, 0.24500858755494165), (1424, 0.2365933474695981), (2354, 0.26858627272463476), (2366, 0.287300934287206), (2555, 0.31929385954224265), (2556, 0.31929385954224265), (2557, 0.31929385954224265), (2558, 0.31929385954224265)]
#
#
#
# ['That', '’', 's', 'same']
# [(15, 0.10485292857286373), (56, 0.2073097646087272), (169, 0.4140173356362207), (2559, 0.8801239518728331)]
#
#
#
# ['When', 'it', '’', 's', 'straight', 'soldier', 'glue', 'it', '’', 's', 'Neosporin']
# [(15, 0.112152497338346), (56, 0.22174209285281388), (78, 0.3450677858944919), (331, 0.2573510535569732), (685, 0.3611877132752734), (1527, 0.42353440960013633), (2560, 0.4706978646821432), (2561, 0.4706978646821432)]
#
#
#
# ['So', 'know', 'in', 'previously', 'met', 'husband', 'dated', 'bunch', 'losers']
# [(212, 0.15642296703559755), (217, 0.21371498143228768), (547, 0.372992739657125), (589, 0.31868256918746624), (663, 0.35455286965818394), (1650, 0.26180813337011394), (1727, 0.3989822767141285), (1728, 0.372992739657125), (2562, 0.4434116837700731)]
#
#
#
# ['And', 'then', 'meet', 'dream', 'guy', 'who', '’', 's', 'like', 'way', 'handsome', 'me', 'league', 'graduated', 'Harvard', 'Business', 'School']
# [(10, 0.15674469455760856), (15, 0.04122491203960856), (41, 0.08854947780082231), (56, 0.08150775497899208), (90, 0.10573070126157329), (126, 0.2655300963052117), (234, 0.2910826088772809), (452, 0.23612783955489944), (674, 0.3113647791335159), (1190, 0.2655300963052117), (1191, 0.24869908655078632), (1192, 0.2655300963052117), (1193, 0.2910826088772809), (1618, 0.22608989268990143), (1726, 0.2910826088772809), (1741, 0.3113647791335159), (2563, 0.34603737819966235)]
#
#
#
# ['Worked', 'hard', 'trap', 'ass']
# [(32, 0.3392457706128048), (371, 0.4849965179915546), (1020, 0.4704113973306117), (2564, 0.6545256312161145)]
#
#
#
# ['Got', 'propose', 'me']
# [(10, 0.31911798081650633), (1936, 0.6339104484199712), (2565, 0.7045007151902594)]
#
#
#
# ['Oh', 'God', 'got', 'married', 'dreams', 'coming', 'true', 'got', 'pregnant', 'recently', 'bought', 'home', 'together']
# [(26, 0.1805590349252456), (74, 0.27056033639707383), (98, 0.2139906496028471), (131, 0.3139214109104276), (138, 0.23926608835603116), (546, 0.23540794124881337), (728, 0.27802753909604394), (1204, 0.27802753909604394), (1209, 0.3254092427206416), (1970, 0.3254092427206416), (2117, 0.3480832378770994), (2566, 0.3868446886171122)]
#
#
#
# ['And', 'uh', 'weeks', 'escrow', 'process', 'discovered', 'beautiful', 'Harvard', 'educated', 'husband', 'debt']
# [(90, 0.11255538131573696), (142, 0.3314626785361171), (217, 0.17754808752970885), (303, 0.27296070188794896), (687, 0.3314626785361171), (1191, 0.26475205579453365), (1286, 0.27296070188794896), (2206, 0.3314626785361171), (2567, 0.368373316246189), (2568, 0.368373316246189), (2569, 0.368373316246189)]
#
#
#
# ['And', 'me', 'hard', 'earned', 'money', 'paid', 'off']
# [(10, 0.23809004367189848), (90, 0.16060146311093432), (371, 0.3894783846186745), (524, 0.4729528745519594), (1064, 0.44214492398178507), (1138, 0.35066495714426194), (1430, 0.4729528745519594)]
#
#
#
# ['So', 'turns', 'out', 'he', '’', 's', 'trapped', 'me']
# [(10, 0.27944326194683067), (15, 0.07349546296500276), (56, 0.14531141222723426), (487, 0.36965663909902235), (491, 0.47338505756769594), (1025, 0.3642502067703282), (1650, 0.3642502067703282), (1747, 0.5189398846974401)]
#
#
#
# ['How', 'it']
# [(21, 0.9023364359144376), (78, 0.4310324308230531)]
#
#
#
# ['How', 'bamboozle', 'me']
# [(10, 0.3381882604901167), (21, 0.5729008029948262), (2570, 0.7466012124250484)]
#
#
#
# ['Oh']
# [(26, 1.0)]
#
#
#
# ['Maybe', 'went', 'Harvard', 'Business', 'School', 'epicenter', 'white', 'collar', 'crime']
# [(75, 0.24071953692148346), (392, 0.28430077637814904), (1190, 0.30354117330431213), (1191, 0.28430077637814904), (1192, 0.30354117330431213), (1963, 0.35593716757135224), (2571, 0.39557320713332605), (2572, 0.39557320713332605), (2573, 0.39557320713332605)]
#
#
#
# ['Enron', '’', 'd', 'ass']
# [(15, 0.09063061239629151), (32, 0.39429927048495755), (333, 0.5075270101473897), (2574, 0.7607433939000422)]
#
#
#
# ['And', 'now', 'don', '’', 't', 'work', 'die']
# [(11, 0.23700878757519192), (15, 0.09777495254958198), (90, 0.2507661942116909), (115, 0.3023236817054636), (322, 0.4778003300705036), (460, 0.4713858292819747), (1653, 0.5740085758273697)]
#
#
#
# ['Why', 'think', 'I', '’', 'm', 'performing', 'seven', 'half', 'months', 'pregnant']
# [(15, 0.06189170582357701), (22, 0.169292965192007), (43, 0.1791188770158135), (58, 0.38495298382210724), (88, 0.46745757263082266), (125, 0.2908718465031338), (403, 0.3633483728596282), (455, 0.34659053468833395), (457, 0.3633483728596282), (546, 0.3161405457652157)]
#
#
#
# ['All', 'right', 'I', '’', 've', 'Ali', 'Wong']
# [(0, 0.39097313939787637), (2, 0.517431571377217), (15, 0.08319125697258922), (22, 0.22755382782768313), (104, 0.43190225614473843), (376, 0.3549690785570741), (564, 0.4562460277319563)]
#
#
#
# ['Have', 'good', 'night', 'everybody']
# [(64, 0.5476395981565296), (199, 0.4474856425281106), (819, 0.4922346117169159), (909, 0.5074963618490834)]
#
#
#
# ['Thank', 'you']
# [(72, 0.8777440399607728), (127, 0.47912983659269354)]

# %% [markdown]
# # routine for sentence similarity 'autocorrelation'

# %%
sent_vecs = word2sent_vec(w2v_model, spec_sents2)

def cos_sim(sent1, sent2):
    norm = np.linalg.norm(sent1) * np.linalg.norm(sent2)
    cosine_similarity = np.dot(sent1, sent2) / norm
    return cosine_similarity
# Out:
# errors:  618
# [ 0.17626953  0.09503174  0.08703613 -0.10314941 -0.01245117 -0.13623047
#   0.07421875 -0.20605469  0.22558594  0.18481445  0.03173828 -0.01074219
#  -0.05670166 -0.13232422  0.02966309  0.05444336 -0.01359558  0.06640625
#   0.2265625   0.18920898  0.14404297  0.04663086 -0.11798096  0.09448242
#  -0.04492188  0.15319824 -0.23486328  0.2006836   0.16351318  0.03601074
#  -0.16040039 -0.01345825 -0.10290527  0.22509766  0.02441406 -0.13452148
#   0.12915039  0.03851318 -0.08831787  0.11376953 -0.07458496 -0.01345062
#   0.13208008  0.12039852 -0.21484375  0.0916748  -0.00611115  0.02709961
#   0.16419983  0.15124512 -0.05786133  0.38378906 -0.0222168   0.20458984
#   0.04443359  0.12182617 -0.09223175  0.18554688  0.09051514  0.01553345
#  -0.0637207  -0.1706543  -0.2890625  -0.01391602  0.05932617  0.06689453
#  -0.30688477  0.0980835  -0.11120605  0.08883667  0.06994629 -0.10693359
#  -0.14550781 -0.1015625  -0.2397461  -0.01660156 -0.06658936  0.01281738
#  -0.08776855 -0.35498047  0.3359375  -0.16210938 -0.06695557  0.23535156
#   0.0894165  -0.08099365 -0.04174805  0.11816406 -0.05322266  0.0803833
#  -0.09643555  0.07049561 -0.0078125  -0.12133026 -0.14111328 -0.09326172
#   0.00201416 -0.1953125   0.16040039 -0.03881836  0.07678223 -0.19921875
#   0.14874268  0.10498047  0.18554688 -0.1496582  -0.12127686 -0.01123047
#   0.01198208 -0.0324707  -0.11340332 -0.0871582  -0.06750488 -0.09558105
#   0.07714844 -0.04785156  0.05029297 -0.06494141 -0.13232422  0.07885742
#   0.0116272  -0.06347656 -0.07348633 -0.08178711  0.10510254  0.13598633
#  -0.05932617 -0.11914062 -0.03778076  0.1352539   0.02648926 -0.01171875
#  -0.06225586 -0.05078125  0.11254883  0.0324707   0.08052063 -0.21142578
#  -0.11767578  0.12841797 -0.07885742 -0.11547852 -0.13500977  0.18847656
#  -0.00708008  0.125      -0.06787109  0.03088379 -0.24365234 -0.17755127
#   0.1875     -0.05029297  0.0335083  -0.09765625  0.11352539 -0.01806641
#  -0.03344727 -0.02191162 -0.16748047 -0.15063477 -0.06091309  0.18066406
#   0.0512085   0.05712891  0.02246094  0.00732422  0.1965332  -0.15136719
#   0.07489014 -0.2084961  -0.09594727  0.04077148 -0.07788086 -0.08789062
#  -0.1850586  -0.09686279  0.1381836  -0.2319336  -0.28125     0.12805176
#  -0.20043945 -0.03222656 -0.18066406  0.02514648  0.04470825 -0.09570312
#  -0.01928711  0.20483398 -0.26611328  0.08447266 -0.09423828  0.1494751
#  -0.14604187  0.04846191  0.09807587  0.04882812  0.07524109 -0.29003906
#  -0.06863403 -0.03149414 -0.0369873  -0.05224609 -0.06689453  0.00561523
#   0.01135254 -0.21533203 -0.00732422 -0.02978516  0.05065918  0.0670166
#  -0.02050781  0.08081055  0.07748413 -0.11024475 -0.01196289  0.09777832
#  -0.09338379  0.10705566 -0.18481445 -0.1270752  -0.13867188 -0.1743164
#   0.2138977  -0.11608887  0.00830078 -0.08044434  0.22680664  0.11328125
#  -0.05456543 -0.11242676 -0.02941895  0.0579834  -0.01367188  0.10205078
#  -0.21191406  0.05285645 -0.11157227 -0.05474854  0.12353516  0.02380371
#   0.15722656  0.04858398 -0.16113281 -0.09082031 -0.17285156 -0.02685547
#   0.17871094 -0.13378906  0.3022461  -0.10351562  0.06005859  0.19238281
#   0.22070312  0.05010986 -0.01977539  0.01849365  0.13024902  0.04541016
#  -0.05895996  0.00927734  0.1159668  -0.13427734 -0.1281128   0.11962891
#   0.03430176  0.35546875 -0.19116211 -0.13891602 -0.11816406  0.01367188
#  -0.05065918 -0.11425781  0.07714844  0.1574707   0.03656006 -0.03637695
#  -0.11242676 -0.08618164  0.08673096 -0.03451538  0.15673828  0.12188721
#   0.06222534 -0.21582031 -0.10180664 -0.12158203 -0.0012207  -0.12902832
#   0.07983398  0.00488281 -0.27441406  0.09350586 -0.26489258  0.02636719
#  -0.1796875  -0.05267334 -0.11291504  0.26171875 -0.08221436 -0.00585938]
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide

# %%
# similarity adjacency routine / "auto-correlation" / joke coherence length detector

def sentence_sim_dist(sent_vecs, chunk_size):

    sim_dist_size = 2*chunk_size + 1
    sim_dist = np.zeros(2*chunk_size + 1)
    end_index = len(sent_vecs)
    # scan through all sentences!

    for i in range(chunk_size, end_index - chunk_size):
        sent_mid = sent_vecs[i]
        for j in range(sim_dist_size):
            k = i + j - chunk_size
            sim_dist[j] += cos_sim(sent_mid, sent_vecs[k])
    norm = sim_dist[chunk_size]
    sim_dist = sim_dist/norm
    return sim_dist

chunk_size = 8
sim_dist = sentence_sim_dist(sent_vecs, chunk_size)

for i in range(2*chunk_size + 1):
    print(i, sim_dist[i])
# Out:
# 0 0.4210972731739153
# 1 0.4222640256896749
# 2 0.42419274690943076
# 3 0.42815181875359964
# 4 0.4315037802516595
# 5 0.44128574252743635
# 6 0.4545895643773861
# 7 0.48914211404191144
# 8 1.0
# 9 0.4893452214841378
# 10 0.45447602289708344
# 11 0.4410195282184755
# 12 0.43122311917712436
# 13 0.42795565810072805
# 14 0.42383711427097465
# 15 0.421975395027481
# 16 0.4204784464249993
