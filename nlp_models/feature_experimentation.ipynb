# %%
# Importing modules
import pandas as pd
import os
import numpy as np

cwd = os.getcwd()
pickled_data = '/Users/johnpapaioannou/Desktop/insight/project/nlp_models/full_transcripts.pkl'

print(pickled_data)
# Read data into papers
specials = pd.read_pickle(pickled_data)

# Print head
specials.head()
specials.shape
# Out:
# /Users/johnpapaioannou/Desktop/insight/project/nlp_models/full_transcripts.pkl
# (126, 2)

# %% [markdown]
# # testing various reading level metrics to use as possible proxies to 'wittiness' of the comedians

# %%
import textstat

test_data = specials.iloc[0,1]
print('flesch reading ease: ', textstat.flesch_reading_ease(test_data))
print('smog index: ', textstat.smog_index(test_data))
print('flesch kincaid grade: ', textstat.flesch_kincaid_grade(test_data))
print('coleman liau index: ', textstat.coleman_liau_index(test_data))
print('automated readability index: ', textstat.automated_readability_index(test_data))

# dale chall is different from the rest, uses a lookup table of the 3,000 most commonly used words
print('dale chall readability score: ', textstat.dale_chall_readability_score(test_data))
print('difficult words: ', textstat.difficult_words(test_data))
print('linsear write formula: ', textstat.linsear_write_formula(test_data))
print('gunning fog: ', textstat.gunning_fog(test_data))
print('text standard: ', textstat.text_standard(test_data, float_output=True))

def text_standard(doc):
    return textstat.text_standard(doc, float_output=True)


readability = specials.transcript.map(text_standard)
dale_chall = specials.transcript.map(lambda x: textstat.dale_chall_readability_score(x))
# Out:
# flesch reading ease:  89.48
# smog index:  7.6
# flesch kincaid grade:  4.7
# coleman liau index:  7.02
# automated readability index:  7.8
# dale chall readability score:  1.56
# difficult words:  429
# linsear write formula:  3.583333333333333
# gunning fog:  6.91
# text standard:  8.0

# %%
# readability statistics
print('READABILITY SCORE')
print('\n mean: ', readability.mean())
print('\n1st quartile: ', np.quantile(readability, 0.25))
print('2nd quantil: ', np.quantile(readability, 0.5))
print('3rd quantile: ', np.quantile(readability, 0.75))
print('\ncomedian: ', specials.iloc[readability.idxmin(),0], ' min readability: ', readability.min())
print('comedian: ', specials.iloc[readability.idxmax(),0], ' max readability: ', readability.max())

smart_index = []
mid_index = []
low_index = []
for i in range(len(readability)):
    if readability[i] >= 7:
        smart_index.append(i)
    if readability[i] < 7 and readability[i] > 5:
        mid_index.append(i)
    if readability[i] <= 5:
        low_index.append(i)
smart_comics = specials.iloc[smart_index,0]
mid_comics = specials.iloc[mid_index,0]
low_comics = specials.iloc[low_index,0]
print('\nsmart comics:n', list(smart_comics))
print('\nmid_comics: \n', list(mid_comics))
print('\nlow_comics: \n', list(low_comics))
# Out:
# READABILITY SCORE
#
#  mean:  6.0
#
# 1st quartile:  5.0
# 2nd quantil:  6.0
# 3rd quantile:  7.0
#
# comedian:  maz jobrani  min readability:  1.0
# comedian:  russell brand  max readability:  11.0
#
# smart comics:n ['adam devine', 'adam sandler', 'bert kreischer', 'bill hicks', 'bill maher', 'bo burnham', 'brian regan', 'chelsea peretti', 'd l hughley', 'demetri martin', 'donald glover', 'dylan moran', 'eddie izzard', 'eddie murphy', 'ellen degeneres', 'emily heller', 'fahim anwar', 'gabriel iglesias', 'jerry seinfeld', 'john mulaney', 'lenny bruce', 'lewis black', 'michael mcintyre', 'neal brennan', 'nikki glaser', 'norm macdonald', 'pete holmes', 'rowan atkinson', 'russell brand', 'stewart lee', 'todd barry', 'tom segura', 'volker pispers']
#
# mid_comics:
#  ['al madrigal', 'ali wong', 'anjelah johnson', 'aziz ansari', 'brad williams', 'bridget everett', 'cedric the entertainer', 'colin quinn', 'craig ferguson', 'dana carvey', 'daniel sloss', 'david cross', 'deray davis', 'doug stanhope', 'eddie griffin', 'frankie boyle', 'fred armisen', 'george carlin', 'hannah gadsby', 'hannibal buress', 'henry rollins', 'iliza shlesinger', 'jeff foxworthy', 'jim gaffigan', 'jim jefferies', 'jim norton', 'jimmy carr', 'jo koy', 'john leguizamo', 'louis ck', 'marc maron', 'michelle wolf', 'mike birbiglia', 'mo amer', 'nick offerman', 'pablo francisco', 'patton oswalt', 'ricky gervais', 'robin williams', 'russell howard', 'sebastian maniscalco', 'todd glass', 'trevor noah']
#
# low_comics:
#  ['adel karam', 'amy schumer', 'anthony jeselnik', 'ari shaffir', 'big jay oakerson', 'bill burr', 'brent morin', 'chris rock', 'chris tucker', 'cristela alonzo', 'daniel tosh', 'dave attell', 'dave chappelle', 'enissa amani', 'erik griffin', 'gina yashere', 'greg davies', 'hasan minhaj', 'jack whitehall', 'jen kirkman', 'joe mandes', 'joe rogan', 'judah friedlander', 'katt williams', 'kavin jay', 'ken jeong', 'kevin hart', 'kevin james', 'kevin smith', 'lisa lampanelli', 'maria bamford', 'marlon wayans', 'maz jobrani', 'michael che', 'mike epps', 'mitch hedberg', 'nate bargatze', 'patrice oneal', 'paul mooney', 'ralphie may', 'ray romano', 'richard pryor', 'ron white', 'roy wood', 'russell peters', 'sarah millican', 'sarah silverman', 'vir das', 'wanda sykes', 'whitney cummings']

# %%
print('DALE-CHALL SCORE')
print('\n mean: ', dale_chall.mean())
print('\n1st quartile: ', np.quantile(dale_chall, 0.25))
print('2nd quantil: ', np.quantile(dale_chall, 0.5))
print('3rd quantile: ', np.quantile(dale_chall, 0.75))
print('\ncomedian: ', specials.iloc[dale_chall.idxmin(),0], ' min DC: ', dale_chall.min())
print('comedian: ', specials.iloc[dale_chall.idxmax(),0], ' max DC: ', dale_chall.max())

smart_index = []
mid_index = []
low_index = []
for i in range(len(dale_chall)):
    if dale_chall[i] >= 5.3:
        smart_index.append(i)
    if dale_chall[i] < 5.3 and dale_chall[i] > 2:
        mid_index.append(i)
    if dale_chall[i] <= 2:
        low_index.append(i)
smart_comics = specials.iloc[smart_index,0]
mid_comics = specials.iloc[mid_index,0]
low_comics = specials.iloc[low_index,0]
print('\nsmart comics:n', list(smart_comics))
print('\nmid_comics: \n', list(mid_comics))
print('\nlow_comics: \n', list(low_comics))
# Out:
# DALE-CHALL SCORE
#
#  mean:  3.407460317460316
#
# 1st quartile:  1.3025000000000002
# 2nd quantil:  5.015
# 3rd quantile:  5.31
#
# comedian:  kevin hart  min DC:  0.9
# comedian:  russell brand  max DC:  6.1
#
# smart comics:n ['al madrigal', 'ali wong', 'bill hicks', 'bill maher', 'bo burnham', 'brian regan', 'chelsea peretti', 'd l hughley', 'dana carvey', 'david cross', 'doug stanhope', 'dylan moran', 'emily heller', 'fahim anwar', 'frankie boyle', 'jack whitehall', 'jeff foxworthy', 'jerry seinfeld', 'john leguizamo', 'lenny bruce', 'lewis black', 'lisa lampanelli', 'maria bamford', 'mike birbiglia', 'neal brennan', 'nick offerman', 'patton oswalt', 'robin williams', 'rowan atkinson', 'russell brand', 'stewart lee', 'todd barry', 'vir das', 'volker pispers']
#
# mid_comics:
#  ['adel karam', 'anjelah johnson', 'colin quinn', 'daniel sloss', 'daniel tosh', 'demetri martin', 'enissa amani', 'erik griffin', 'fred armisen', 'gina yashere', 'greg davies', 'hannah gadsby', 'hannibal buress', 'hasan minhaj', 'henry rollins', 'iliza shlesinger', 'jim gaffigan', 'jim norton', 'joe mandes', 'judah friedlander', 'ken jeong', 'michael mcintyre', 'michelle wolf', 'mitch hedberg', 'mo amer', 'pablo francisco', 'patrice oneal', 'pete holmes', 'roy wood', 'russell howard', 'sarah silverman', 'wanda sykes']
#
# low_comics:
#  ['adam devine', 'adam sandler', 'amy schumer', 'anthony jeselnik', 'ari shaffir', 'aziz ansari', 'bert kreischer', 'big jay oakerson', 'bill burr', 'brad williams', 'brent morin', 'bridget everett', 'cedric the entertainer', 'chris rock', 'chris tucker', 'craig ferguson', 'cristela alonzo', 'dave attell', 'dave chappelle', 'deray davis', 'donald glover', 'eddie griffin', 'eddie izzard', 'eddie murphy', 'ellen degeneres', 'gabriel iglesias', 'george carlin', 'jen kirkman', 'jim jefferies', 'jimmy carr', 'jo koy', 'joe rogan', 'john mulaney', 'katt williams', 'kavin jay', 'kevin hart', 'kevin james', 'kevin smith', 'louis ck', 'marc maron', 'marlon wayans', 'maz jobrani', 'michael che', 'mike epps', 'nate bargatze', 'nikki glaser', 'norm macdonald', 'paul mooney', 'ralphie may', 'ray romano', 'richard pryor', 'ricky gervais', 'ron white', 'russell peters', 'sarah millican', 'sebastian maniscalco', 'todd glass', 'tom segura', 'trevor noah', 'whitney cummings']

# %% [markdown]
# # based on inspection, doesn't pass a sniff test in terms of the comedians' material and general intelligence of material, e.g. George Carlin, Ricky Gervais, Trevor Noah are ranked low

# %%
# function to parts-of-speech tag if it helps the model

import nltk

def pos_parser(blurb):
    pos_of_interest = ['NN', 'NNS']
    tokens = nltk.word_tokenize(blurb)
    token_pos = nltk.pos_tag(tokens)

    pos_list = []
    for i in range(len(pos_of_interest)):
        pos_list.append([])
    
    i=0
    for pos in pos_of_interest:
        for token_tuple in token_pos:
            if token_tuple[1] == pos:
                pos_list[i].append(token_tuple[0])
        i+=1

    #clean up list, count duplicates? remove punctuation?
    all_nouns = pos_list[0] + pos_list[1]
    return all_nouns

# %%
# Load the regular expression library
import re

# Remove punctuation
specials['transcript'] = specials['transcript'].map(lambda x: re.sub('[,\'”+"\.+!?]', '', x))
# Remove ellipsis, r'(\w+)\.{3,}'
#specials['transcript'] = specials['transcript'].map(lambda x: re.sub('(\w+)\.{3,}', '', x))

# Convert the titles to lowercase
tickle me their sizes are really different different no no i was traumatized i noticed something else there too they sell water in a bag and pistachios in a bottle go figure they are so comfortable with their sex organs no problem here things are censored there it’s all good if a guy feels like it he just whips it out right there and then i went to the hotel depressed my room was on the 13th floor out on the balcony having a smoke i used to smoke back then i saw the hotel manager walking around with a guy talking about removing a banana tree and doing this and that i saw him and i guess he needed to pee mind you i’m on 13th floor he unzipped his pants and started rolling it out like a rope and i’m standing there on the 13th floor and i see something really long really and he’s just talking as he was pulling it out and he was going about his business on the other side a woman had this red sack on her head she’s topless with a tree leaf here and walking along big ass she was going to pass in front of the guy as he was peeing right in front of him for a second i imagined he was gonna tell his friend to grab the other end of it and go like this “come after that… after that i told ali i don’t want to go to africa from now on if i travel i’d be better off going to china in china 17 centimeters you’d be a champ rocco the stud you laughed when i said rocco guess you know who he is rocco is a porn star she blushed she knows him only men are supposed to laugh at that i said rocco and she went… speaking of porn you know statistics show that we arabs rank number one in watching porn sites seriously but we don’t admit it you know who else doesn’t admit it women you ask a woman do you watch porn she goes “ew disgusting a new bride would be sitting there and the groom comes along thinking that she’s… he’d asked her before “do you watch porn she said “no that’s disgusting don’t mention porn he starts undressing and turns around she’s there in high heels and ...

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2018)
nltk.download('wordnet')
stemmer = SnowballStemmer('english')
comedy_cliche = ['like', 'know', 'say', 'look', 'come', 'right', 'go', 'think']
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/johnpapaioannou/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# lemmatize and remove stop words!
# include profanity filter and prediction!
import numpy as np
from profanity_check import predict, predict_prob
    
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            if token not in comedy_cliche:
                result.append(lemmatize_stemming(token))
    return result

def profanity_prob(text):
    prof = predict_prob(text)
    return np.mean(prof)
def prof_ratio(text):
    prof = predict(text)
    return sum(prof)/len(prof)
# Out:
# //anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.20.2 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LinearSVC from version 0.20.2 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.20.2 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator _SigmoidCalibration from version 0.20.2 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# //anaconda3/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator CalibratedClassifierCV from version 0.20.2 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
processed_transcripts = specials['transcript'].map(preprocess)

# %% [markdown]
# # test profanity checker on comedians and check statistics of distribution

# %%
profanity_score = processed_transcripts.map(profanity_prob)
profanity_ratio = processed_transcripts.map(prof_ratio)

# %%
print('using profanity probability: \n')
print('index: ', profanity_score.idxmax(), 'profanity_score: ', profanity_score.max())
print('index: ', profanity_score.idxmin(), 'profanity_score: ', profanity_score.min())
print('mean: ', profanity_score.mean())
print('1st quartile: ', np.quantile(profanity_score, 0.25))
print('2nd quartile: ', np.quantile(profanity_score, 0.5))
print('3rd quartile: ', np.quantile(profanity_score, 0.75))

print('cleanest comedian: ', specials.iloc[profanity_score.idxmin(),0])
print('dirtiest comedian: ', specials.iloc[profanity_score.idxmax(),0])

print('\n using profanity ratio: \n')
print('index: ', profanity_ratio.idxmax(), 'profanity_ratio: ', profanity_ratio.max())
print('index: ', profanity_ratio.idxmin(), 'profanity_ratio: ', profanity_ratio.min())
print('mean: ', profanity_ratio.mean())
print('1st quartile: ', np.quantile(profanity_ratio, 0.25))
print('2nd quartile: ', np.quantile(profanity_ratio, 0.5))
print('3rd quartile: ', np.quantile(profanity_ratio, 0.75))
print('cleanest comedian: ', specials.iloc[profanity_ratio.idxmin(),0])
print('dirtiest comedian: ', specials.iloc[profanity_ratio.idxmax(),0])

dirty_index = []
mid_index = []
clean_index = []
for i in range(len(profanity_ratio)):
    if profanity_ratio[i] >= 0.05:
        dirty_index.append(i)
    if profanity_ratio[i] < 0.05 and profanity_ratio[i] > 0.0125:
        mid_index.append(i)
    if profanity_ratio[i] <= 0.0125:
        clean_index.append(i)
dirty_comics = specials.iloc[dirty_index,0]
mid_comics = specials.iloc[mid_index,0]
clean_comics = specials.iloc[clean_index,0]
print('\n', len(dirty_comics), ' dirty comics: \n', list(dirty_comics))
print('\n', len(mid_comics), ' mid_comics: \n', list(mid_comics))
print('\n', len(clean_comics), ' clean_comics: \n', list(clean_comics))
# Out:
# using profanity probability:
#
# index:  39 profanity_score:  0.20204321366986272
# index:  48 profanity_score:  0.11873984605639645
# mean:  0.14759849328659844
# 1st quartile:  0.13304297592419778
# 2nd quartile:  0.14259010705479971
# 3rd quartile:  0.15885285047468992
# cleanest comedian:  fred armisen
# dirtiest comedian:  eddie griffin
#
#  using profanity ratio:
#
# index:  39 profanity_ratio:  0.13200136612021857
# index:  6 profanity_ratio:  0.0004253509145044662
# mean:  0.035377660992139806
# 1st quartile:  0.012828790445954169
# 2nd quartile:  0.02862499612973996
# 3rd quartile:  0.04939467034208156
# cleanest comedian:  anjelah johnson
# dirtiest comedian:  eddie griffin
#
#  31  dirty comics:
#  ['adam devine', 'adam sandler', 'big jay oakerson', 'bill burr', 'brent morin', 'bridget everett', 'cedric the entertainer', 'chris rock', 'd l hughley', 'dave chappelle', 'deray davis', 'doug stanhope', 'eddie griffin', 'eddie murphy', 'erik griffin', 'jim jefferies', 'jo koy', 'joe rogan', 'katt williams', 'ken jeong', 'kevin hart', 'kevin smith', 'lisa lampanelli', 'louis ck', 'marlon wayans', 'michael che', 'mike epps', 'paul mooney', 'ralphie may', 'richard pryor', 'ron white']
#
#  64  mid_comics:
#  ['al madrigal', 'ali wong', 'amy schumer', 'anthony jeselnik', 'ari shaffir', 'aziz ansari', 'bert kreischer', 'bill hicks', 'bill maher', 'bo burnham', 'brad williams', 'chelsea peretti', 'chris tucker', 'colin quinn', 'craig ferguson', 'cristela alonzo', 'dana carvey', 'daniel sloss', 'daniel tosh', 'david cross', 'demetri martin', 'donald glover', 'eddie izzard', 'fahim anwar', 'frankie boyle', 'george carlin', 'gina yashere', 'greg davies', 'hannah gadsby', 'hannibal buress', 'hasan minhaj', 'iliza shlesinger', 'jack whitehall', 'jen kirkman', 'jim norton', 'jimmy carr', 'joe mandes', 'john leguizamo', 'judah friedlander', 'lenny bruce', 'lewis black', 'marc maron', 'michael mcintyre', 'mo amer', 'neal brennan', 'nick offerman', 'nikki glaser', 'norm macdonald', 'patrice oneal', 'patton oswalt', 'pete holmes', 'ricky gervais', 'robin williams', 'roy wood', 'russell brand', 'russell howard', 'russell peters', 'sarah millican', 'sarah silverman', 'todd glass', 'tom segura', 'vir das', 'wanda sykes', 'whitney cummings']
#
#  31  clean_comics:
#  ['adel karam', 'anjelah johnson', 'brian regan', 'dave attell', 'dylan moran', 'ellen degeneres', 'emily heller', 'enissa amani', 'fred armisen', 'gabriel iglesias', 'henry rollins', 'jeff foxworthy', 'jerry seinfeld', 'jim gaffigan', 'john mulaney', 'kavin jay', 'kevin james', 'maria bamford', 'maz jobrani', 'michelle wolf', 'mike birbiglia', 'mitch hedberg', 'nate bargatze', 'pablo francisco', 'ray romano', 'rowan atkinson', 'sebastian maniscalco', 'stewart lee', 'todd barry', 'trevor noah', 'volker pispers']

# %% [markdown]
# # create dataframe to store comedians with their edginess score based on profanity checker's ratio of profane words to total words per transcript

# %%
# create dataframe with comedian and edginess score columns and export to pkl
df = specials.copy()
df['edginess'] = profanity_ratio
#print(df.head())
df = df.drop(columns=['transcript'])
#print(df.head())

# set PG, PG-13 and R limits
pg_max = 0.009
pg13_max = 0.002
def edge_quant(score):
    if score >= pg13_max:
        score_bin = 3
    if score < pg13_max and score > pg_max:
        score_bin = 2
    if score <= pg_max:
        score_bin = 1
    return score_bin

edge_bin = df.edginess.map(edge_quant)
df['rating'] = edge_bin

# %%
def uppercase_names(name):
    name = name.split(" ")
    name = name[0].capitalize() + " " + name[1].capitalize()
    return name
df.comedian = df.comedian.map(uppercase_names)

# %%
import pickle

data_path = '/Users/johnpapaioannou/Desktop/insight/project/data/'
file_path = data_path + 'comedian_metrics.pkl'
df.to_pickle(file_path)

# %%
comic1 = 'amy schumer'
comic2 = 'nate bargatze'
comic1 = comic1.split(" ")

comic1 = comic1[0].capitalize() + " " + comic1[1].capitalize()
print('comic', comic1)
# Out:
# comic Amy Schumer

# %%
transcript_nouns = specials.transcript.map(pos_parser)

# %%
from itertools import compress

test_clean = predict(transcript_nouns[0])
test_clean = 1 - test_clean
list(compress(transcript_nouns[0], test_clean))
# Out:
# ['[',
#  'rock',
#  'music',
#  'chatter',
#  'man',
#  'crowd',
#  'man',
#  '[',
#  ']',
#  's',
#  'everybody',
#  'seat',
#  '[',
#  'crowd',
#  ']',
#  'thing',
#  'gon',
#  'blast',
#  'tonight',
#  'crowd',
#  'cause',
#  'adult',
#  'man',
#  ']',
#  'laughter',
#  'laughter',
#  'kid',
#  'laughter',
#  ']',
#  't',
#  'kind',
#  'weirdo',
#  'laughter',
#  ']',
#  'face',
#  'adult',
#  'kid',
#  'school',
#  'lunch',
#  'today',
#  '”',
#  'quality',
#  'face',
#  'child',
#  'mom',
#  'bouncy',
#  'ball',
#  'birthday',
#  't',
#  'cool',
#  '[',
#  '[',
#  'laughter',
#  'bouncy',
#  'ball',
#  'driveway',
#  'like…',
#  'midair',
#  'phrase',
#  'youth',
#  'adult',
#  'Everything',
#  'child',
#  'midair',
#  'abyss',
#  'midair',
#  'midair',
#  'midair',
#  'midair.',
#  'mom',
#  's',
#  'laughter',
#  'course',
#  'midair',
#  'honey',
#  'anything',
#  'air…',
#  'laughter',
#  'midair',
#  '‘',
#  'ground',
#  'd',
#  'boy.',
#  '[',
#  'laughter',
#  'cool',
#  'level',
#  'elevator',
#  'deal',
#  '[',
#  'stairs',
#  's',
#  '[',
#  'laughter',
#  'elevator',
#  'day',
#  'cause',
#  'adult',
#  'adult',
#  'fabric',
#  'suede',
#  'elevator',
#  '”',
#  't',
#  'laughter',
#  ']',
#  'elevator',
#  '”',
#  'laughter',
#  '”',
#  'age',
#  'age',
#  'existence',
#  'age',
#  'kid',
#  '”',
#  'period',
#  'Transformer',
#  '[',
#  '[',
#  'laughter',
#  'ping',
#  'confusing',
#  'weird',
#  'grade',
#  'time',
#  'guy',
#  'voice',
#  'day',
#  'like…',
#  '[',
#  'voice',
#  'kickball',
#  '[',
#  'voice',
#  ']',
#  'day',
#  'kickball',
#  'laughter',
#  '[',
#  'laughter',
#  'to…',
#  'school',
#  'thing',
#  'guy',
#  'lot',
#  't',
#  'realize',
#  'life',
#  '%',
#  'chance',
#  '%',
#  'time',
#  'time',
#  'gust',
#  'wind',
#  'sexy',
#  'gust',
#  'just…',
#  'laughter',
#  ']',
#  'someone',
#  'car',
#  'door',
#  'month',
#  'heat',
#  'car',
#  'door',
#  'the…',
#  '[',
#  'nape',
#  'neck',
#  '-And',
#  '[',
#  'laughter',
#  't',
#  'sex',
#  'laughter',
#  ']',
#  'bloomer',
#  'erection',
#  'wind',
#  'moment',
#  'man',
#  '’',
#  'life',
#  'laughter',
#  'wind',
#  '[',
#  'laughter',
#  'mean',
#  'thing',
#  'nation',
#  'dad',
#  'boy',
#  'son',
#  'gay',
#  'fine',
#  'me.',
#  '”',
#  'laughter',
#  'laughter',
#  ']',
#  '“',
#  '[',
#  'laughter',
#  'posterboard',
#  'march',
#  'laughter',
#  'sister',
#  'wind',
#  'march',
#  'goddamn',
#  'weekend',
#  'laughter',
#  'practice',
#  '”',
#  'ton',
#  'bluff',
#  'wind',
#  'laughter',
#  'gust',
#  'season',
#  '”',
#  'man',
#  '[',
#  'weed',
#  'cool',
#  'elevator',
#  'elevator',
#  'age',
#  'pack',
#  'bunch',
#  'girl',
#  'taller',
#  'just…',
#  're',
#  'like–',
#  'afternoon',
#  '[',
#  'girl',
#  'elevator',
#  'size',
#  '’',
#  '’',
#  'laughter',
#  'laughter',
#  'stage',
#  'elevator',
#  'friend',
#  'girl',
#  's',
#  'friend',
#  '’',
#  'elevator',
#  'laughter',
#  'boobs.',
#  '’',
#  'time',
#  's',
#  'elevator',
#  '”',
#  'time',
#  's',
#  'story',
#  '”',
#  'laughter',
#  '”',
#  'friend',
#  '’',
#  's',
#  'mind',
#  'friend',
#  '’',
#  's',
#  'like…',
#  'laughter',
#  ']',
#  'something',
#  'day',
#  'around.',
#  '”',
#  '”',
#  '”',
#  '[',
#  'laughter',
#  ']',
#  'puddle…',
#  '”',
#  'end',
#  'story',
#  'laughter',
#  'friend',
#  'mind',
#  'friend',
#  ']',
#  'difference',
#  'adult',
#  'child',
#  'adult',
#  'story',
#  'laughter',
#  ']',
#  'dog',
#  'story',
#  'child',
#  'storytelling',
#  'crew',
#  '‘',
#  'laughter',
#  'epic',
#  'adventure',
#  'puddle',
#  'laughter',
#  ']',
#  'level',
#  'time.',
#  'tomorrow',
#  'show',
#  'laughter',
#  'one',
#  'home',
#  'spouse',
#  'whoever',
#  'room',
#  '”',
#  'like…',
#  'laughter',
#  't',
#  'happen',
#  'stuff',
#  '’',
#  'll',
#  'order',
#  'ton',
#  'Freeze',
#  '”',
#  'gasps',
#  ']',
#  'dicks.',
#  '”',
#  'laughter',
#  ']',
#  'laughter',
#  'applause',
#  ']',
#  'time',
#  'life',
#  'laughter',
#  ']',
#  'laughter',
#  'time…',
#  'life',
#  'd',
#  'depressing',
#  'female',
#  'laughter',
#  ']',
#  'time',
#  'life',
#  'deathbed',
#  'kid',
#  'kid',
#  'time',
#  'life',
#  '”',
#  'kid',
#  'laughter',
#  'dying',
#  'time',
#  'life',
#  '”',
#  'laughter',
#  'muscle',
#  'mouth',
#  'like…',
#  '“',
#  'this.',
#  'laughter',
#  '“',
#  'comedy',
#  'show',
#  '“',
#  'TV',
#  't',
#  'list',
#  'guy',
#  's',
#  'set',
#  'ton',
#  'dad',
#  'laughter',
#  'time',
#  'life',
#  'laughter',
#  'kid',
#  '’',
#  'plug',
#  't',
#  'march',
#  'dude',
#  'date',
#  'act',
#  'time',
#  'life',
#  'babe',
#  'gun',
#  'laughter',
#  'thing',
#  '[',
#  'laughter',
#  'torture',
#  'Anything',
#  't',
#  'finger',
#  'in…',
#  'laughter',
#  ']',
#  'conversation',
#  'car',
#  'ride',
#  'home',
#  'gunpoint',
#  'insane',
#  'life',
#  'flash',
#  'eyes.',
#  't',
#  't',
#  'finger',
#  '[',
#  'laughter',
#  'laughter',
#  ']',
#  'babe',
#  '[',
#  'laughter',
#  'hero',
#  'babe',
#  't',
#  'care',
#  'cause',
#  'finger',
#  'laughter',
#  ']',
#  'dude',
#  'em',
#  'out.',
#  'laughter',
#  'blowjob',
#  'situation',
#  'running',
#  'bar',
#  'fight',
#  '-I',
#  'bar',
#  '[',
#  'laughter',
#  ']',
#  'rapport',
#  'bar',
#  'fight',
#  'like…',
#  'laughter',
#  'cause',
#  't',
#  'meme',
#  'day',
#  'made.',
#  'laughter',
#  ']',
#  'everyone',
#  'phone',
#  'internet',
#  'time',
#  'bar',
#  'fight',
#  'watch',
#  's',
#  'gon',
#  'gon',
#  'fight',
#  't',
#  'fight',
#  'laughter',
#  'laughter',
#  't',
#  'none',
#  'fight',
#  'sense',
#  'phenomenon',
#  'd',
#  '[',
#  'laughter',
#  'd',
#  'd',
#  'hear',
#  'd',
#  'way',
#  'fight',
#  'act',
#  'deaf',
#  'Nobody',
#  's',
#  'gon',
#  'deaf',
#  'guy',
#  'monster',
#  't',
#  'hear',
#  ']',
#  'piece',
#  'deaf',
#  'guy',
#  'guy',
#  '”',
#  's',
#  't',
#  'hear',
#  'hearing',
#  'aid',
#  't',
#  'hear',
#  'laughter',
#  'roll.',
#  'laughter',
#  ']',
#  't',
#  'qualms.',
#  '”',
#  'deaf',
#  'guy',
#  'crew',
#  '‘',
#  'guy',
#  's',
#  'bro',
#  '[',
#  'laughter',
#  's',
#  'd',
#  'like…',
#  'laughter',
#  'someone',
#  'intimidating',
#  's',
#  'party',
#  'somebody',
#  'drink',
#  'man',
#  'you.',
#  '”',
#  'guy',
#  'crankhead',
#  't',
#  'move.',
#  'laughter',
#  'respect',
#  'like…',
#  's',
#  'laughter',
#  '”',
#  'rex',
#  'impression',
#  'gon',
#  'tonight',
#  '[',
#  'crowd',
#  's',
#  'somebody',
#  '”',
#  'guy',
#  '[',
#  'moan',
#  'No.',
#  'laughter',
#  'you.',
#  'gon',
#  'guy',
#  'gon',
#  'man',
#  'warming',
#  'laughter',
#  'property',
#  's',
#  ']',
#  'mass',
#  'death',
#  'drown.',
#  'guys',
#  'wait',
#  'vacation',
#  'recline',
#  'beach',
#  'chair',
#  'view',
#  'bear',
#  'drowning',
#  'laughter',
#  'laughter',
#  '[',
#  'Man',
#  'lot',
#  'thought',
#  'gon',
#  'wear',
#  'day',
#  'cape…',
#  'punchline',
#  'cape',
#  'cape',
#  's',
#  'funny',
#  'cape.',
#  '”',
#  'closing',
#  'cape',
#  'stuff',
#  '[',
#  'laughter',
#  ']',
#  'end',
#  'show',
#  'driving',
#  'home',
#  'guy',
#  'fashion',
#  'choice',
#  'man.',
#  '”',
#  'cape',
#  'embarrassing',
#  'get',
#  'intimate',
#  'cape',
#  'kid',
#  '[',
#  'laughter',
#  ']',
#  '’',
#  'cause',
#  'ta-dah',
#  'sidewalk',
#  '[',
#  'laughter',
#  'mud',
#  'horrible',
#  'hands.',
#  'hallway',
#  'closet',
#  'dad',
#  'cape',
#  'day',
#  'top',
#  'stairs',
#  'kid',
#  'base',
#  'stairs',
#  'hallway',
#  'closet',
#  'help',
#  '”',
#  's',
#  'laughter',
#  ']',
#  'laughter',
#  't',
#  'hiding',
#  'closet',
#  'come',
#  's',
#  'closet',
#  'poof',
#  'Ta-dah',
#  ']',
#  'kid',
#  'laughter',
#  ']',
#  'lot',
#  'exertion',
#  ']',
#  'time',
#  'dad',
#  'magic',
#  'laughter',
#  'kind',
#  'thing',
#  '’',
#  'laughter',
#  '-Hmm',
#  '[',
#  'applause',
#  ']',
#  'dad',
#  'bigot.',
#  '”',
#  'bit',
#  'bit',
#  'laughter',
#  'bit.',
#  'bigot',
#  'friend',
#  'laughter',
#  'thing',
#  'doesn',
#  't',
#  'laughter',
#  't',
#  'call',
#  'time',
#  'adult',
#  'youth',
#  'dad',
#  'kid',
#  't',
#  'notice',
#  'grocery',
#  'store',
#  'dude',
#  'adult',
#  'pretty',
#  'gay',
#  'man',
#  'child',
#  'guy',
#  'laughter',
#  ']',
#  'dad',
#  'man',
#  'like…',
#  '[',
#  ']',
#  'cheeks',
#  'laughter',
#  ']',
#  'dad',
#  'type',
#  'dude',
#  'gay',
#  'man',
#  'laughter',
#  ']',
#  't',
#  'laughter',
#  'kinky',
#  'rougher',
#  't',
#  'think',
#  'case',
#  'dad',
#  'man',
#  's',
#  '”',
#  'fairy',
#  'boy',
#  'magic',
#  'laughter',
#  ']',
#  'word',
#  'fairy',
#  '”',
#  'mind',
#  'like…',
#  '[',
#  'voice',
#  'fairy',
#  '[',
#  'laughter',
#  'pixie',
#  'dust',
#  'fairy',
#  'laughter',
#  ']',
#  'dad',
#  's',
#  'pixie',
#  'dust',
#  'pixie',
#  'dust.',
#  'laughter',
#  'laughter',
#  ']',
#  'person',
#  'poster',
#  'laughter',
#  'comedy',
#  'time',
#  'gon',
#  'gon',
#  'home',
#  '[',
#  'laughter',
#  'laughter',
#  '“',
#  '”',
#  'TV',
#  'stuff',
#  'cheering',
#  'man',
#  'cool',
#  'man',
#  'lot',
#  'fun',
#  'part',
#  'beer',
#  'face',
#  'laughter',
#  ']',
#  's',
#  's',
#  'kid',
#  'counter',
#  'laughter',
#  'bro',
#  'prison',
#  '”',
#  'prison',
#  'time',
#  'laughter',
#  'immunity',
#  'boost',
#  '”',
#  'cause',
#  '’',
#  's',
#  'celebrity',
#  'Everyone',
#  's',
#  'guy',
#  'guy',
#  'thing',
#  '”',
#  'party',
#  't',
#  'party',
#  'cocktail',
#  'shrimp',
#  'hunt',
#  'cocktail',
#  'shrimp',
#  'ran',
#  'part',
#  'laughter',
#  ']',
#  'man',
#  'fact',
#  'opposite',
#  'cool',
#  'kind',
#  'racist',
#  'cause',
#  '”',
#  'laughter',
#  ']',
#  'actor',
#  'man',
#  '”',
#  'impression',
#  'anyone',
#  'one',
#  '’',
#  's',
#  'cool',
#  's',
#  'size',
#  'is…',
#  'guy',
#  'guy',
#  '[',
#  'laughter',
#  'laughter',
#  'laughter',
#  'applause',
#  ']',
#  '“',
#  'crowd',
#  'man',
#  'time',
#  'moment',
#  'life',
#  'cause',
#  't',
#  't',
#  'cause',
#  'head',
#  'hair',
#  'cause',
#  'man',
#  'nice',
#  'high',
#  'eye',
#  'contact',
#  'laughter',
#  'Nothing',
#  'Nothing',
#  '”',
#  'stop',
#  'light',
#  't',
#  'all.',
#  '”',
#  'time',
#  'dude',
#  'like…',
#  'cooler',
#  'story',
#  'nothing',
#  'laughter',
#  ']',
#  'future',
#  'youth',
#  'time',
#  'traveler',
#  'sent',
#  'time',
#  'traveler',
#  'person',
#  '”',
#  'laughter',
#  '”',
#  't',
#  'name',
#  't',
#  'world',
#  'laughter',
#  ']',
#  'then…',
#  'peace',
#  'sign',
#  'douche',
#  'maneuver',
#  '”',
#  'motorcycle',
#  'sitting',
#  'car',
#  'laughter',
#  ']',
#  'man',
#  'butthole',
#  'laughter',
#  'butthole',
#  'tightest.',
#  '”',
#  'ego',
#  't',
#  'use',
#  'context',
#  'is…',
#  '[',
#  'crowd',
#  'show',
#  'compliment',
#  'show',
#  'something',
#  '[',
#  'crowd',
#  'butthole',
#  'butthole',
#  '[',
#  'crowd',
#  'butthole',
#  'butthole',
#  'grade',
#  'teacher',
#  'laughter',
#  'class',
#  'gold',
#  'laughter',
#  'right',
#  'TV',
#  'show',
#  'laughter',
#  'script.',
#  'question',
#  'improv',
#  'guy',
#  'context',
#  'butthole',
#  'butthole.',
#  '”',
#  'intersection…',
#  '“',
#  'butthole',
#  'man',
#  'laughter',
#  'butthole',
#  'tightest',
#  '”',
#  't',
#  'anything',
#  'fact',
#  'man…',
#  'size…',
#  'fact',
#  'laughter',
#  '”',
#  'someone',
#  'crosswalk',
#  'day',
#  'night',
#  ...]

# %%
transcript_nouns_clean = transcript_nouns
for i in range(len(transcript_nouns)):
    clean_filter = predict(transcript_nouns[i])
    clean_filter = 1 - clean_filter
    transcript_nouns_clean[i] = list(compress(transcript_nouns[i], clean_filter))
    transcript_nouns[i] = " ".join(transcript_nouns[i])

#print(transcript_nouns)
print(transcript_nouns_clean)
# Out:
# 0      [ rock music chatter man crowd man [ ] s every...
# 1      man cue action [ piano day smile ♪ way style ♪...
# 2      du evening evening soul evening space thank wa...
# 3      dog s welcome [ applause name s house waterfal...
# 4      stage t gon ♪ ♪ ♪ niggas this♪ ♪ moonshine♪ ♪ ...
# 5      something lot behavior city night ” crowd stra...
# 6      trip wardrobe jewelry collection marriage cour...
# 7      friend ’ wife day influence husband name word....
# 8      collection set Adulthood night intermission wa...
# 9      house everybody house tonight s mix a… minorit...
# 10     [ applause male presenter [ rock music crowd a...
# 11     [ crowd rock music hey [ applause [ applause ]...
# 12     cheering applause ] announcer arena [ audience...
# 13     horse s moon play horse man hat cloak horse ri...
# 14     variety standup special greeting purpose show ...
# 15     farm E farm pig E snort farm E male product gi...
# 16     bluesy rock music pop rock music time tonight ...
# 17     Shot confrontation security guard backstage pa...
# 18     man welcome [ right thank right thank man toni...
# 19     picture nightstand… picture night in… “ day gi...
# 20     jazz music look legend game [ guy gig [ [ band...
# 21     date show bit tomfoolery voice growl motorcycl...
# 22     time pain chocolate city right event leader ri...
# 23     music audience audience ] y tonight everybody ...
# 24     disco music girl hello baby girl tramp lady ’ ...
# 25     day everybody south affinity south share pain ...
# 26     s night chick fun – like… gon gon gon night ” ...
# 27     ♪ ♪ ♪ ♪ stage king comedy man–D.L [ hell city ...
# 28     Man talk phenomenon kill effeminate t bit loti...
# 29     music playing audience music playing dialogue ...
#                              ...
# 96     ooh ooh ooh ooh ooh ooh ooh ooh ooh ooh ooh oo...
# 97     ” part it. right pork chop t anything s you… r...
# 98     “ s good “ Pablo Pablo right Pablo “ music ’ S...
# 99     [ funk music applause ] pair front row audienc...
# 100    audience kid game fort game okay bike path sca...
# 101    cause see course writer s character move perfo...
# 102    cheering everybody s seat audience Look cheeri...
# 103    house comedy fun discomfort laughter cast come...
# 104    comedy way now… club gon club home club… night...
# 105    act film act audience footage shortest film au...
# 106    laboratory sort s science abomination doctor s...
# 107    Thank head woman peach hair friend night ovati...
# 108    ] s taste mouth something fix gram marijuana m...
# 109    show series comedy audience TV broadcast video...
# 110    announcer applause ] anthem song problem right...
# 111    ♪♪ applause applause ♪♪ man announcer ♪♪ appla...
# 112    stage ‘ world minute t depressing world countr...
# 113    please man name [ right audience man Everybody...
# 114    – snack welcome – show bit advice advice examp...
# 115    ‘ – ‘ audience s record someone record bit cra...
# 116    music cheering applause applause father ] day ...
# 117    Chapter stage story hour er sort bit show inte...
# 118    fire announcer stage [ applause [ [ yeah Nothi...
# 119    fun face positivity there… way room act comedy...
# 120    yeah relax and– t family t use toilet paper… s...
# 121    distant traffic presenter [ hip hop intro musi...
# 122    % mind look way evening right name gon time to...
# 123    part program policy war terror timescale “ bir...
# 124    goodness saying… …you lying tweeting president...
# 125    special evening hometown lot s lot year t hara...
# Name: transcript, Length: 126, dtype: object

# %%
processed_nouns = transcript_nouns.map(preprocess)
processed_nouns_clean = transcript_nouns_clean.map(preprocess)

# %%
print(processed_transcripts[0])
print(type(processed_transcripts[0]))
# Out:
# ['rock', 'music', 'play', 'indistinct', 'chatter', 'crowd', 'cheer', 'thank', 'ladi', 'gentlemen', 'adam', 'devin', 'loud', 'cheer', 'everybodi', 'thank', 'thank', 'thank', 'yeah', 'thank', 'guy', 'seat', 'thank', 'thank', 'guy', 'jack', 'crowd', 'whoop', 'fulli', 'juic', 'thing', 'excit', 'thank', 'guy', 'have', 'gonna', 'blast', 'tonight', 'crowd', 'cheer', 'excit', 'excit', 'caus', 'adult', 'laughter', 'excit', 'lock', 'laughter', 'littl', 'level', 'geek', 'laughter', 'rememb', 'open', 'present', 'vocabulari', 'thank', 'mama', 'laughter', 'guy', 'talk', 'kind', 'weirdo', 'say', 'thing', 'yeah', 'mama', 'thank', 'mama', 'vocabulari', 'go', 'laughter', 'face', 'adult', 'lock', 'chuckl', 'adult', 'thing', 'school', 'drop', 'enjoy', 'lunch', 'today', 'laughter', 'whisper', 'chees', 'question', 'qualiti', 'meat', 'littl', 'level', 'excit', 'face', 'month', 'child', 'swear', 'give', 'super', 'bounci', 'ball', 'birthday', 'guy', 'poor', 'parent', 'cool', 'adam', 'chuckl', 'laughter', 'give', 'bounci', 'ball', 'month', 'straight', 'driveway', 'snatch', 'midair', 'chuckl', 'phrase', 'youth', 'midair', 'midair', 'adult', 'child', 'catch', 'midair', 'soar', 'abi', 'snatch', 'midair', 'midair', 'midair', 'midair', 'midair', 'jesus', 'christ', 'laughter', 'cours', 'catch', 'midair', 'honey', 'catch', 'laughter', 'technic', 'midair', 'caus', 'catch', 'grind', 'call', 'pick', 'fuck', 'idiot', 'dumb', 'littl', 'laughter', 'kid', 'cool', 'kid', 'get', 'level', 'geek', 'get', 'fulli', 'geek', 'elev', 'long', 'deal', 'chuckl', 'fuck', 'stair', 'stupid', 'stupid', 'laughter', 'elev', 'have', 'crappi', 'caus', 'adult', 'wear', 'boot', 'shitti', 'asshol', 'adult', 'fabric', 'sued', 'rain', 'outsid', 'elev', 'defeat', 'boot', 'boot', 'wasn', 'verbal', 'idiot', 'laughter', 'elev', 'go', 'boot', 'laughter', 'boot', 'think', 'kid', 'weird', 'agre', 'worst', 'human', 'exist', 'mutant', 'cute', 'littl', 'have', 'month', 'period', 'human', 'transform', 'squeal', 'laughter', 'ping', 'ping', 'ping', 'confus', 'weird', 'girl', 'obvious', 'obvious', 'weird', 'dude', 'rememb', 'weird', 'eighth', 'grade', 'confus', 'time', 'rememb', 'voic', 'chang', 'sudden', 'overnight', 'high', 'voic', 'wanna', 'play', 'kickbal', 'regular', 'voic', 'fuck', 'kickbal', 'motherfuck', 'laughter', 'tri', 'lay', 'pass', 'hennessi', 'laughter', 'daddi', 'tri', 'guy', 'guy', 'rememb', 'middl', 'school', 'weird', 'thing', 'year', 'peopl', 'realiz', 'year', 'life', 'chanc', 'dick', 'hard', 'time', 'constant', 'sexual', 'yeah', 'chuckl', 'rememb', 'time', 'gust', 'wind', 'laughter', 'sexi', 'sexi', 'gust', 'laughter', 'slam', 'door', 'month', 'august', 'rememb', 'heat', 'come', 'door', 'imit', 'wind', 'blow', 'nape', 'neck', 'imit', 'wind', 'scream', 'laughter', 'confus', 'perv', 'laughter', 'late', 'bloomer', 'sudden', 'erect', 'wind', 'confus', 'moment', 'young', 'life', 'laughter', 'want', 'fuck', 'wind', 'laughter', 'wind', 'sexual', 'mean', 'wind', 'sexual', 'stupid', 'chuckl', 'weird', 'nowaday', 'real', 'thing', 'wind', 'sexual', 'sweep', 'nation', 'yeah', 'make', 'sens', 'chuckl', 'weird', 'weird', 'confus', 'year', 'caus', 'legitim', 'speak', 'perfect', 'okay', 'fine', 'go', 'laughter', 'weird', 'fulli', 'wind', 'sexual', 'laughter', 'laughter', 'posterboard', 'marker', 'gotta', 'march', 'shit', 'laughter', 'sister', 'want', 'piss', 'stand', 'want', 'fuck', 'wind', 'gotta', 'march', 'goddamn', 'weekend', 'laughter', 'rememb', 'take', 'soccer', 'practic', 'okay', 'kid', 'bluff', 'tri', 'fuck', 'wind', 'laughter', 'cheer', 'tri', 'catch', 'good', 'gust', 'chuckl', 'niño', 'season', 'gotta', 'stupid', 'talk', 'weed', 'legal', 'california', 'cheer', 'guy', 'weed', 'cool', 'yeah', 'girl', 'get', 'elev', 'come', 'elev', 'weird', 'girl', 'caus', 'girl', 'grow', 'quick', 'pack', 'girl', 'bunch', 'littl', 'girl', 'girl', 'half', 'feet', 'taller', 'squeal', 'grow', 'afternoon', 'grow', 'half', 'feet', 'happen', 'squeal', 'happen', 'gigant', 'girl', 'come', 'elev', 'size', 'laughter',  ...
# <class 'list'>

# %% [markdown]
# # test out Bag of Words and TF-IDF for topic modeling

# %%
dictionary = gensim.corpora.Dictionary(processed_transcripts)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_transcripts]

# %%
from gensim import corpora, models

tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

from pprint import pprint

for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.024753029451099865),
#  (1, 0.018092186132780186),
#  (2, 0.007546821075548641),
#  (3, 0.009270450670934032),
#  (4, 0.0048448773333210305),
#  (5, 0.012329470691312324),
#  (6, 0.005891628709269734),
#  (7, 0.0060613267333453884),
#  (8, 0.10783276303900255),
#  (9, 0.014390712784939037),
#  (10, 0.04745362685949976),
#  (11, 0.012329470691312324),
#  (12, 0.020611843197837352),
#  (13, 0.006285692534634889),
#  (14, 0.0035976781962347593),
#  (15, 0.014568065041159914),
#  (16, 0.0051328174768728654),
#  (17, 0.003612514916276046),
#  (18, 0.003374439946445253),
#  (19, 0.0017504424560072203),
#  (20, 0.0037734105377743203),
#  (21, 0.06699177235331806),
#  (22, 0.0015627473695663185),
#  (23, 0.003374439946445253),
#  (24, 0.004236779794561871),
#  (25, 0.024939900472620204),
#  (26, 0.0032609993310217474),
#  (27, 0.024753029451099865),
#  (28, 0.010793034588704278),
#  (29, 0.0020102429036422433),
#  (904, 0.0013282673181714527),
#  (905, 0.02889421570436238),
#  (906, 0.009066190350989692),
#  (907, 0.00047796770649678353),
#  (908, 0.018132380701979384),
#  (909, 0.024753029451099865),
#  (910, 0.003984801954514358),
#  (911, 0.02115053242417939),
#  (912, 0.0014821172466135061),
#  (913, 0.004635225335467016),
#  (914, 0.019530905869097635),
#  (915, 0.011625779611253806),
#  (916, 0.01647065694457484),
#  (917, 0.04904466484852793),
#  (918, 0.0013011686808368154),
#  (919, 0.02056536071088982),
#  (920, 0.006423042695627164),
#  (921, 0.014048218277914321),
#  (922, 0.008986063586583545),
#  (923, 0.06484375026638528),
#  (924, 0.006433518844117123),
#  (925, 0.0015627473695663185),
#  (926, 0.0009676575118298138),
#  (927, 0.0014073821601170338),
#  (928, 0.001146446852782334),
#  (929, 0.00195954461116166),
#  (931, 0.07711471598700326),
#  (932, 9.559354129935671e-05),
#  (933, 0.0037578612192655228),
#  (934, 0.000988078164409004),
#  (935, 0.020611843197837352),
#  (936, 0.010426878787897402),
#  (937, 0.0027629053142047906),
#  (938, 0.0005829906340804902),
#  (939, 0.0016185897719414577),
#  (941, 0.014048218277914321),
#  (942, 0.0018143411279013548),
#  (943, 0.061647353456561624),
#  (944, 0.013570005612569876),
#  (945, 0.009428819359307361)]

# %%
# running LDA on bag-of-words first
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=20, id2word=dictionary, passes=2, workers=2)
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))

# a lot of typical communicative language in standup is getting picked up but they're meaningless!

#add to stop words, ['like', 'know', 'say', 'look', 'come', 'right', 'go', 'think']
# Out:
# Topic: 0
# Words: 0.014*"say" + 0.013*"go" + 0.012*"fuck" + 0.009*"peopl" + 0.008*"thing" + 0.007*"want" + 0.007*"gonna" + 0.007*"shit" + 0.006*"tell" + 0.006*"caus"
# Topic: 1
# Words: 0.020*"fuck" + 0.013*"go" + 0.012*"gonna" + 0.010*"say" + 0.010*"peopl" + 0.009*"shit" + 0.009*"time" + 0.008*"thing" + 0.007*"yeah" + 0.006*"okay"
# Topic: 2
# Words: 0.013*"peopl" + 0.011*"gonna" + 0.010*"say" + 0.010*"fuck" + 0.010*"go" + 0.008*"time" + 0.008*"want" + 0.008*"thing" + 0.007*"good" + 0.007*"yeah"
# Topic: 3
# Words: 0.015*"peopl" + 0.015*"fuck" + 0.011*"want" + 0.011*"go" + 0.010*"thing" + 0.008*"littl" + 0.008*"say" + 0.007*"time" + 0.007*"yeah" + 0.007*"love"
# Topic: 4
# Words: 0.023*"fuck" + 0.015*"peopl" + 0.011*"go" + 0.010*"want" + 0.010*"gonna" + 0.008*"shit" + 0.007*"thing" + 0.007*"okay" + 0.007*"come" + 0.006*"say"
# Topic: 5
# Words: 0.019*"fuck" + 0.018*"go" + 0.014*"say" + 0.011*"shit" + 0.010*"peopl" + 0.009*"gonna" + 0.008*"want" + 0.008*"time" + 0.008*"thing" + 0.007*"tell"
# Topic: 6
# Words: 0.010*"want" + 0.009*"fuck" + 0.009*"peopl" + 0.008*"go" + 0.008*"say" + 0.007*"time" + 0.007*"shit" + 0.006*"gonna" + 0.006*"thing" + 0.006*"yeah"
# Topic: 7
# Words: 0.024*"audienc" + 0.018*"laugh" + 0.014*"go" + 0.013*"fuck" + 0.010*"peopl" + 0.010*"gonna" + 0.008*"say" + 0.007*"thing" + 0.007*"want" + 0.007*"year"
# Topic: 8
# Words: 0.019*"go" + 0.012*"fuck" + 0.009*"want" + 0.009*"peopl" + 0.009*"yeah" + 0.009*"say" + 0.008*"thing" + 0.007*"gonna" + 0.006*"good" + 0.006*"love"
# Topic: 9
# Words: 0.012*"say" + 0.011*"fuck" + 0.011*"go" + 0.009*"shit" + 0.009*"want" + 0.009*"peopl" + 0.007*"gonna" + 0.007*"time" + 0.006*"caus" + 0.006*"tell"
# Topic: 10
# Words: 0.016*"fuck" + 0.016*"say" + 0.013*"peopl" + 0.012*"go" + 0.009*"thing" + 0.009*"want" + 0.008*"yeah" + 0.008*"gonna" + 0.008*"time" + 0.006*"shit"
# Topic: 11
# Words: 0.016*"fuck" + 0.012*"shit" + 0.011*"gonna" + 0.011*"want" + 0.011*"peopl" + 0.009*"say" + 0.009*"yeah" + 0.009*"go" + 0.008*"time" + 0.007*"caus"
# Topic: 12
# Words: 0.014*"go" + 0.014*"peopl" + 0.013*"say" + 0.011*"fuck" + 0.010*"want" + 0.008*"yeah" + 0.008*"thing" + 0.008*"gonna" + 0.008*"time" + 0.006*"shit"
# Topic: 13
# Words: 0.014*"laughter" + 0.014*"say" + 0.012*"fuck" + 0.010*"peopl" + 0.009*"go" + 0.008*"shit" + 0.007*"want" + 0.006*"time" + 0.006*"mean" + 0.006*"gonna"
# Topic: 14
# Words: 0.014*"go" + 0.012*"fuck" + 0.009*"gonna" + 0.008*"peopl" + 0.008*"want" + 0.007*"yeah" + 0.007*"say" + 0.007*"shit" + 0.006*"thing" + 0.006*"time"
# Topic: 15
# Words: 0.024*"fuck" + 0.015*"shit" + 0.014*"go" + 0.013*"peopl" + 0.013*"gonna" + 0.011*"say" + 0.010*"yeah" + 0.010*"audienc" + 0.007*"want" + 0.007*"thing"
# Topic: 16
# Words: 0.014*"go" + 0.011*"peopl" + 0.011*"say" + 0.010*"shit" + 0.009*"yeah" + 0.009*"want" + 0.009*"time" + 0.009*"fuck" + 0.009*"gonna" + 0.007*"love"
# Topic: 17
# Words: 0.013*"fuck" + 0.013*"audienc" + 0.012*"peopl" + 0.010*"go" + 0.009*"gonna" + 0.009*"yeah" + 0.009*"laugh" + 0.008*"shit" + 0.007*"say" + 0.007*"caus"
# Topic: 18
# Words: 0.023*"nigga" + 0.014*"fuck" + 0.013*"motherfuck" + 0.011*"shit" + 0.010*"go" + 0.009*"gonna" + 0.009*"peopl" + 0.008*"want" + 0.008*"say" + 0.008*"white"
# Topic: 19
# Words: 0.025*"fuck" + 0.010*"peopl" + 0.009*"say" + 0.009*"go" + 0.008*"want" + 0.008*"shit" + 0.008*"time" + 0.007*"gonna" + 0.006*"love" + 0.005*"tell"

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=3, id2word=dictionary, passes=2, workers=2)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.001*"nigga" + 0.000*"fuck" + 0.000*"crowd" + 0.000*"motherfuck" + 0.000*"rowan" + 0.000*"laughter" + 0.000*"mama" + 0.000*"hasan" + 0.000*"drummer" + 0.000*"brent"
# Topic: 1 Word: 0.001*"laughter" + 0.000*"fuck" + 0.000*"nigga" + 0.000*"audienc" + 0.000*"fuckin" + 0.000*"cheer" + 0.000*"applaus" + 0.000*"motherfuck" + 0.000*"chuckl" + 0.000*"trump"
# Topic: 2 Word: 0.000*"laughter" + 0.000*"explet" + 0.000*"fuck" + 0.000*"dick" + 0.000*"pinki" + 0.000*"applaus" + 0.000*"porn" + 0.000*"josi" + 0.000*"prom" + 0.000*"jigsaw"

# %%
# iterative process of filtering out meaningless filler words
fillers = ['peopl', 'think', 'audienc', 'time', 'caus', 'laughter']

# %%
# now repeat LDA modeling but on preprocessed nouns from transcripts
dic_nouns_clean = gensim.corpora.Dictionary(processed_nouns_clean)

dic_nouns_clean.filter_extremes(no_below=5, no_above=0.1, keep_n=50)

bow_corpus_nouns_clean = [dictionary.doc2bow(doc) for doc in processed_nouns_clean]

# %%
# running LDA on bag-of-words first
lda_model = gensim.models.LdaMulticore(bow_corpus_nouns_clean, num_topics=3, id2word=dictionary, passes=2, workers=2)
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.009*"kind" + 0.009*"thing" + 0.006*"year" + 0.005*"kid" + 0.005*"room" + 0.005*"countri" + 0.005*"women" + 0.004*"stuff" + 0.004*"wife" + 0.004*"life"
# Topic: 1
# Words: 0.022*"thing" + 0.011*"year" + 0.008*"life" + 0.007*"friend" + 0.006*"woman" + 0.006*"women" + 0.006*"joke" + 0.006*"girl" + 0.006*"kid" + 0.006*"kind"
# Topic: 2
# Words: 0.017*"thing" + 0.009*"year" + 0.008*"friend" + 0.008*"kid" + 0.007*"life" + 0.007*"woman" + 0.007*"girl" + 0.006*"babi" + 0.006*"hous" + 0.005*"guy"

# %%
# now repeat tf-idf for nouns
tfidf_nouns = models.TfidfModel(bow_corpus_nouns_clean)
corpus_tfidf_nouns = tfidf_nouns[bow_corpus_nouns_clean]

# %%
lda_model_tfidf_nouns = gensim.models.LdaMulticore(corpus_tfidf_nouns, num_topics=4, id2word=dictionary, passes=2, workers=2)
for idx, topic in lda_model_tfidf_nouns.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.000*"laughter" + 0.000*"audienc" + 0.000*"titti" + 0.000*"dude" + 0.000*"cheer" + 0.000*"goddamn" + 0.000*"damn" + 0.000*"tit" + 0.000*"boyfriend" + 0.000*"cream"
# Topic: 1 Word: 0.000*"audienc" + 0.000*"laughter" + 0.000*"folk" + 0.000*"presid" + 0.000*"nigga" + 0.000*"robot" + 0.000*"gorilla" + 0.000*"cheer" + 0.000*"caus" + 0.000*"massag"
# Topic: 2 Word: 0.001*"laughter" + 0.000*"motherfuck" + 0.000*"applaus" + 0.000*"mama" + 0.000*"audienc" + 0.000*"cheer" + 0.000*"chuckl" + 0.000*"dude" + 0.000*"gang" + 0.000*"prom"
# Topic: 3 Word: 0.000*"laughter" + 0.000*"crowd" + 0.000*"burger" + 0.000*"perkin" + 0.000*"pfft" + 0.000*"headmast" + 0.000*"balconi" + 0.000*"medit" + 0.000*"halamaha" + 0.000*"tit"
